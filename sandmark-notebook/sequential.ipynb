# %% [markdown]
# # Throughput

# %% [markdown]
# ## Import Data

# %%
import json
import os, glob
import pandas as pd
import pandas.io.json as pdjson
import seaborn as sns

sns.set(style="whitegrid")

# %%
baseline="Stock"

# %%
data_frames = []

for file in glob.glob("*.orun.bench"):
    with open(file) as f:
        data = []
        for l in f:
            data.append(json.loads(l))
        df = pdjson.json_normalize(data)
        df['variant'] = file.replace(".orun.bench","")
        data_frames.append(df)

df = pd.concat (data_frames, sort=False)
df = df.sort_values(['name']) 
# Uncomment the following to display all the lines in pandas output
pd.set_option('display.max_rows', df.shape[0]+1)
df
# Out:
# <ipython-input-99-0958bbb059cf>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pdjson.json_normalize(data)
#                                          name  \
# 10                      LU_decomposition.1024
# 10                      LU_decomposition.1024
# 10                      LU_decomposition.1024
# 10                      LU_decomposition.1024
# 22                          alt-ergo.fill.why
# 22                          alt-ergo.fill.why
# 22                          alt-ergo.fill.why
# 22                          alt-ergo.fill.why
# 12                          alt-ergo.yyll.why
# 12                          alt-ergo.yyll.why
# 12                          alt-ergo.yyll.why
# 12                          alt-ergo.yyll.why
# 34                                     bdd.26
# 34                                     bdd.26
# 34                                     bdd.26
# 34                                     bdd.26
# 41                            binarytrees5.21
# 41                            binarytrees5.21
# 42                            binarytrees5.21
# 41                            binarytrees5.21
# 33                 chameneos_redux_lwt.600000
# 33                 chameneos_redux_lwt.600000
# 33                 chameneos_redux_lwt.600000
# 33                 chameneos_redux_lwt.600000
# 48               coq.AbstractInterpretation.v
# 47               coq.AbstractInterpretation.v
# 47               coq.AbstractInterpretation.v
# 47               coq.AbstractInterpretation.v
# 6                           coq.BasicSyntax.v
# 6                           coq.BasicSyntax.v
# 6                           coq.BasicSyntax.v
# 6                           coq.BasicSyntax.v
# 32                             cpdf.blacktext
# 32                             cpdf.blacktext
# 32                             cpdf.blacktext
# 32                             cpdf.blacktext
# 37                                 cpdf.scale
# 37                                 cpdf.scale
# 38                                 cpdf.scale
# 37                                 cpdf.scale
# 43                               cpdf.squeeze
# 44                               cpdf.squeeze
# 43                               cpdf.squeeze
# 43                               cpdf.squeeze
# 8                        crout-decomposition.
# 8                        crout-decomposition.
# 8                        crout-decomposition.
# 8                        crout-decomposition.
# 42                     cubicle.german_pfs.cub
# 42                     cubicle.german_pfs.cub
# 42                     cubicle.german_pfs.cub
# 43                     cubicle.german_pfs.cub
# 25                   cubicle.szymanski_at.cub
# 25                   cubicle.szymanski_at.cub
# 25                   cubicle.szymanski_at.cub
# 25                   cubicle.szymanski_at.cub
# 27                      durand-kerner-aberth.
# 27                      durand-kerner-aberth.
# 27                      durand-kerner-aberth.
# 27                      durand-kerner-aberth.
# 15         evolutionary_algorithm.10000_10000
# 15         evolutionary_algorithm.10000_10000
# 15         evolutionary_algorithm.10000_10000
# 15         evolutionary_algorithm.10000_10000
# 30                           fannkuchredux.12
# 30                           fannkuchredux.12
# 30                           fannkuchredux.12
# 30                           fannkuchredux.12
# 29                          fannkuchredux2.12
# 29                          fannkuchredux2.12
# 29                          fannkuchredux2.12
# 29                          fannkuchredux2.12
# 53                          fasta3.25_000_000
# 53                          fasta3.25_000_000
# 53                          fasta3.25_000_000
# 54                          fasta3.25_000_000
# 23                          fasta6.25_000_000
# 23                          fasta6.25_000_000
# 23                          fasta6.25_000_000
# 23                          fasta6.25_000_000
# 2                                        fft.
# 2                                        fft.
# 2                                        fft.
# 2                                        fft.
# 16                         floyd_warshall.512
# 16                         floyd_warshall.512
# 16                         floyd_warshall.512
# 16                         floyd_warshall.512
# 37                             frama-c.slevel
# 11                           game_of_life.256
# 11                           game_of_life.256
# 11                           game_of_life.256
# 11                           game_of_life.256
# 14                                grammatrix.
# 14                                grammatrix.
# 14                                grammatrix.
# 14                                grammatrix.
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000
# 40  imrin_mem_rw.10_000_50_000_80_100_000_000
# 45                                        kb.
# 45                                        kb.
# 45                                        kb.
# 46                                        kb.
# 35                                 kb_no_exc.
# 35                                 kb_no_exc.
# 35                                 kb_no_exc.
# 35                                 kb_no_exc.
# 52                               knucleotide.
# 53                               knucleotide.
# 52                               knucleotide.
# 52                               knucleotide.
# 31                              knucleotide3.
# 31                              knucleotide3.
# 31                              knucleotide3.
# 31                              knucleotide3.
# 0                            levinson-durbin.
# 0                            levinson-durbin.
# 0                            levinson-durbin.
# 0                            levinson-durbin.
# 26                               lexifi-g2pp.
# 26                               lexifi-g2pp.
# 26                               lexifi-g2pp.
# 26                               lexifi-g2pp.
# 19                         mandelbrot6.16_000
# 19                         mandelbrot6.16_000
# 19                         mandelbrot6.16_000
# 19                         mandelbrot6.16_000
# 21                 matrix_multiplication.1024
# 21                 matrix_multiplication.1024
# 21                 matrix_multiplication.1024
# 21                 matrix_multiplication.1024
# 36                              menhir.ocamly
# 36                              menhir.ocamly
# 36                              menhir.ocamly
# 36                              menhir.ocamly
# 1                           menhir.sql-parser
# 1                           menhir.sql-parser
# 1                           menhir.sql-parser
# 1                           menhir.sql-parser
# 50                              menhir.sysver
# 50                              menhir.sysver
# 51                              menhir.sysver
# 50                              menhir.sysver
# 44                        minilight.roomfront
# 44                        minilight.roomfront
# 44                        minilight.roomfront
# 45                        minilight.roomfront
# 49                          naive-multilayer.
# 50                          naive-multilayer.
# 49                          naive-multilayer.
# 49                          naive-multilayer.
# 28                           nbody.50_000_000
# 28                           nbody.50_000_000
# 28                           nbody.50_000_000
# 28                           nbody.50_000_000
# 49                           pidigits5.10_000
# 48                           pidigits5.10_000
# 48                           pidigits5.10_000
# 48                           pidigits5.10_000
# 24                          qr-decomposition.
# 24                          qr-decomposition.
# 24                          qr-decomposition.
# 24                          qr-decomposition.
# 18                          quicksort.4000000
# 18                          quicksort.4000000
# 18                          quicksort.4000000
# 18                          quicksort.4000000
# 13                               regexredux2.
# 13                               regexredux2.
# 13                               regexredux2.
# 13                               regexredux2.
# 5                                   revcomp2.
# 5                                   revcomp2.
# 5                                   revcomp2.
# 5                                   revcomp2.
# 51                         sequence_cps.10000
# 51                         sequence_cps.10000
# 52                         sequence_cps.10000
# 51                         sequence_cps.10000
# 3               setrip.-enc_-rseed_1067894368
# 3               setrip.-enc_-rseed_1067894368
# 3               setrip.-enc_-rseed_1067894368
# 3               setrip.-enc_-rseed_1067894368
# 40                        spectralnorm2.5_500
# 40                        spectralnorm2.5_500
# 40                        spectralnorm2.5_500
# 41                        spectralnorm2.5_500
# 9                  test_decompress.64_524_288
# 9                  test_decompress.64_524_288
# 9                  test_decompress.64_524_288
# 9                  test_decompress.64_524_288
# 7                                test_lwt.200
# 7                                test_lwt.200
# 7                                test_lwt.200
# 7                                test_lwt.200
# 47                thread_ring_lwt_mvar.20_000
# 46                thread_ring_lwt_mvar.20_000
# 46                thread_ring_lwt_mvar.20_000
# 46                thread_ring_lwt_mvar.20_000
# 20              thread_ring_lwt_stream.20_000
# 20              thread_ring_lwt_stream.20_000
# 20              thread_ring_lwt_stream.20_000
# 20              thread_ring_lwt_stream.20_000
# 4                    yojson_ydump.sample.json
# 4                    yojson_ydump.sample.json
# 4                    yojson_ydump.sample.json
# 4                    yojson_ydump.sample.json
# 39                             zarith_pi.5000
# 38                             zarith_pi.5000
# 38                             zarith_pi.5000
# 38                             zarith_pi.5000
#
#                                               command   time_secs  \
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.532988
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.218466
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.531972
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.385071
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.566125
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.021685
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.593185
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.616023
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   17.532885
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   18.301929
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   18.339121
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   18.200624
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.582651
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.623276
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.572424
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.270421
# 41         taskset --cpu-list 5 ./binarytrees5.exe 21   12.296776
# 41         taskset --cpu-list 5 ./binarytrees5.exe 21   12.691259
# 42         taskset --cpu-list 5 ./binarytrees5.exe 21   11.725996
# 41         taskset --cpu-list 5 ./binarytrees5.exe 21   12.748200
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.084518
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.258255
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.259385
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.250527
# 48  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  293.342959
# 47  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  322.526510
# 47  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  323.478994
# 47  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  325.257178
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  111.984415
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  113.384733
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  110.976984
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  104.018834
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    3.997935
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    4.017149
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    3.999818
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    4.188315
# 37  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   14.219408
# 37  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   14.229265
# 38  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   13.766666
# 37  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   14.371217
# 43  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.626318
# 44  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.432945
# 43  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.630203
# 43  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.706276
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.378919
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.416446
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.327643
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.378068
# 42  taskset --cpu-list 5 cubicle benchmarks/cubicl...  271.583435
# 42  taskset --cpu-list 5 cubicle benchmarks/cubicl...  271.654957
# 42  taskset --cpu-list 5 cubicle benchmarks/cubicl...  272.682828
# 43  taskset --cpu-list 5 cubicle benchmarks/cubicl...  234.789072
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  570.779414
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  578.129767
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  581.848810
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  566.162048
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.145797
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.153606
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.138931
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.152575
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   71.845517
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   71.858201
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   68.461066
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   74.323333
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   78.609458
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   94.164035
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   98.387937
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   93.480126
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   95.489403
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   90.920677
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   87.460362
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   90.992310
# 53       taskset --cpu-list 5 ./fasta3.exe 25_000_000    8.464174
# 53       taskset --cpu-list 5 ./fasta3.exe 25_000_000    8.255948
# 53       taskset --cpu-list 5 ./fasta3.exe 25_000_000    8.287676
# 54       taskset --cpu-list 5 ./fasta3.exe 25_000_000    7.476167
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.341172
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.757025
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.870499
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.349594
# 2                      taskset --cpu-list 5 ./fft.exe    4.955272
# 2                      taskset --cpu-list 5 ./fft.exe    3.678841
# 2                      taskset --cpu-list 5 ./fft.exe    3.713123
# 2                      taskset --cpu-list 5 ./fft.exe    3.746694
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    4.553231
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    3.683866
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    3.653924
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    3.662433
# 37  taskset --cpu-list 5 frama-c -slevel 100000000...    1.498318
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.519269
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.414043
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.558226
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.415595
# 14              taskset --cpu-list 5 ./grammatrix.exe   94.811698
# 14              taskset --cpu-list 5 ./grammatrix.exe   93.947041
# 14              taskset --cpu-list 5 ./grammatrix.exe   95.695882
# 14              taskset --cpu-list 5 ./grammatrix.exe   94.925338
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.144451
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    6.720169
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.182761
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.199571
# 39  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    8.246158
# 39  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    8.194800
# 39  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    8.185835
# 40  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.947550
# 45                      taskset --cpu-list 5 ./kb.exe    4.215579
# 45                      taskset --cpu-list 5 ./kb.exe    4.217915
# 45                      taskset --cpu-list 5 ./kb.exe    4.181545
# 46                      taskset --cpu-list 5 ./kb.exe    4.133245
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.584991
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.575357
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.626528
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.575042
# 52             taskset --cpu-list 5 ./knucleotide.exe   46.812605
# 53             taskset --cpu-list 5 ./knucleotide.exe   43.457097
# 52             taskset --cpu-list 5 ./knucleotide.exe   46.604469
# 52             taskset --cpu-list 5 ./knucleotide.exe   47.665617
# 31            taskset --cpu-list 5 ./knucleotide3.exe   47.484276
# 31            taskset --cpu-list 5 ./knucleotide3.exe   49.506311
# 31            taskset --cpu-list 5 ./knucleotide3.exe   45.305798
# 31            taskset --cpu-list 5 ./knucleotide3.exe   47.060356
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    2.984550
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    2.967338
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    2.888597
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    3.067796
# 26                    taskset --cpu-list 5 ./main.exe   17.342709
# 26                    taskset --cpu-list 5 ./main.exe   17.403823
# 26                    taskset --cpu-list 5 ./main.exe   17.185935
# 26                    taskset --cpu-list 5 ./main.exe   17.383595
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   41.977878
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   41.076731
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   41.203864
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   39.844158
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    8.484307
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    9.727537
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    8.934777
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    8.446212
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  259.400356
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  234.466711
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  259.275777
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  261.143221
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    7.327255
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    7.370447
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    7.262291
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...
# 53                0.000000   4.10.0+multicore+redzone0             NaN
# 53                0.000000  4.10.0+multicore+redzone32             NaN
# 53                0.000000            4.10.0+multicore             NaN
# 54                     NaN                4.10.0+stock             1.0
# 23                0.638682  4.10.0+multicore+redzone32             NaN
# 23                     NaN                4.10.0+stock             3.0
# 23                0.638693   4.10.0+multicore+redzone0             NaN
# 23                0.595731            4.10.0+multicore             NaN
# 2                      NaN                4.10.0+stock            18.0
# 2                35.104247   4.10.0+multicore+redzone0             NaN
# 2                35.104247  4.10.0+multicore+redzone32             NaN
# 2                35.104264            4.10.0+multicore             NaN
# 16                     NaN                4.10.0+stock            15.0
# 16               38.481655   4.10.0+multicore+redzone0             NaN
# 16               38.481926            4.10.0+multicore             NaN
# 16               38.481655  4.10.0+multicore+redzone32             NaN
# 37                     NaN                4.10.0+stock             3.0
# 11                8.249132   4.10.0+multicore+redzone0             NaN
# 11                8.249132  4.10.0+multicore+redzone32             NaN
# 11                     NaN                4.10.0+stock            18.0
# 11                8.249411            4.10.0+multicore             NaN
# 14                4.810851            4.10.0+multicore             NaN
# 14                     NaN                4.10.0+stock            42.0
# 14                4.705581   4.10.0+multicore+redzone0             NaN
# 14                4.705581  4.10.0+multicore+redzone32             NaN
# 17              110.322628  4.10.0+multicore+redzone32             NaN
# 17                     NaN                4.10.0+stock             7.0
# 17              110.324694            4.10.0+multicore             NaN
# 17              110.322628   4.10.0+multicore+redzone0             NaN
# 39              110.369536   4.10.0+multicore+redzone0             NaN
# 39              110.371604            4.10.0+multicore             NaN
# 39              110.369536  4.10.0+multicore+redzone32             NaN
# 40                     NaN                4.10.0+stock             7.0
# 45               84.854569            4.10.0+multicore             NaN
# 45               78.637302  4.10.0+multicore+redzone32             NaN
# 45               78.638287   4.10.0+multicore+redzone0             NaN
# 46                     NaN                4.10.0+stock             7.0
# 35                     NaN                4.10.0+stock             8.0
# 35               79.476181  4.10.0+multicore+redzone32             NaN
# 35               79.476181   4.10.0+multicore+redzone0             NaN
# 35               79.477052            4.10.0+multicore             NaN
# 52               12.719830            4.10.0+multicore             NaN
# 53                     NaN                4.10.0+stock            11.0
# 52               12.719692  4.10.0+multicore+redzone32             NaN
# 52               12.719692   4.10.0+multicore+redzone0             NaN
# 31             2610.910590   4.10.0+multicore+redzone0             NaN
# 31             2610.910590  4.10.0+multicore+redzone32             NaN
# 31                     NaN                4.10.0+stock             3.0
# 31             2613.889413            4.10.0+multicore             NaN
# 0                94.658831  4.10.0+multicore+redzone32             NaN
# 0                94.637929            4.10.0+multicore             NaN
# 0                      NaN                4.10.0+stock             2.0
# 0                94.658831   4.10.0+multicore+redzone0             NaN
# 26               92.490934  4.10.0+multicore+redzone32             NaN
# 26               92.490934   4.10.0+multicore+redzone0             NaN
# 26                     NaN                4.10.0+stock             1.0
# 26               92.493740            4.10.0+multicore             NaN
# 19                0.000000            4.10.0+multicore             NaN
# 19                0.000000   4.10.0+multicore+redzone0             NaN
# 19                0.000000  4.10.0+multicore+redzone32             NaN
# 19                     NaN                4.10.0+stock             1.0
# 21                6.965498            4.10.0+multicore             NaN
# 21                     NaN                4.10.0+stock            21.0
# 21                6.965288  4.10.0+multicore+redzone32             NaN
# 21                6.965288   4.10.0+multicore+redzone0             NaN
# 36               22.686568            4.10.0+multicore             NaN
# 36                     NaN                4.10.0+stock            50.0
# 36               22.686503   4.10.0+multicore+redzone0             NaN
# 36               22.686503  4.10.0+multicore+redzone32             NaN
# 1                15.144751  4.10.0+multicore+redzone32             NaN
# 1                15.144751   4.10.0+multicore+redzone0             NaN
# 1                15.144822            4.10.0+multicore             NaN
# 1                      NaN                4.10.0+stock            38.0
# 50               30.990187   4.10.0+multicore+redzone0             NaN
# 50               30.676174            4.10.0+multicore             NaN
# 51                     NaN                4.10.0+stock            43.0
# 50               30.990187  4.10.0+multicore+redzone32             NaN
# 44               48.736418   4.10.0+multicore+redzone0             NaN
# 44               48.840422            4.10.0+multicore             NaN
# 44               48.736418  4.10.0+multicore+redzone32             NaN
# 45                     NaN                4.10.0+stock            10.0
# 49              214.409547            4.10.0+multicore             NaN
# 50                     NaN                4.10.0+stock             1.0
# 49              214.396195  4.10.0+multicore+redzone32             NaN
# 49              214.396195   4.10.0+multicore+redzone0             NaN
# 28                     NaN                4.10.0+stock             1.0
# 28                0.000000   4.10.0+multicore+redzone0             NaN
# 28                0.000000            4.10.0+multicore             NaN
# 28                0.000000  4.10.0+multicore+redzone32             NaN
# 49                     NaN                4.10.0+stock            17.0
# 48              104.431343   4.10.0+multicore+redzone0             NaN
# 48              104.431701            4.10.0+multicore             NaN
# 48              104.431343  4.10.0+multicore+redzone32             NaN
# 24               67.405752   4.10.0+multicore+redzone0             NaN
# 24               67.405752  4.10.0+multicore+redzone32             NaN
# 24                     NaN                4.10.0+stock             3.0
# 24               67.403944            4.10.0+multicore             NaN
# 18                     NaN                4.10.0+stock             2.0
# 18                0.000000   4.10.0+multicore+redzone0             NaN
# 18                0.000000  4.10.0+multicore+redzone32             NaN
# 18                0.000000            4.10.0+multicore             NaN
# 13               20.282913   4.10.0+multicore+redzone0             NaN
# 13               20.282931            4.10.0+multicore             NaN
# 13                     NaN                4.10.0+stock            16.0
# 13               20.282913  4.10.0+multicore+redzone32             NaN
# 5                23.104556            4.10.0+multicore             NaN
# 5                23.104471  4.10.0+multicore+redzone32             NaN
# 5                23.104471   4.10.0+multicore+redzone0             NaN
# 5                      NaN                4.10.0+stock            35.0
# 51             5175.202114   4.10.0+multicore+redzone0             NaN
# 51             5166.673713  4.10.0+multicore+redzone32             NaN
# 52                     NaN                4.10.0+stock             1.0
# 51             5183.758343            4.10.0+multicore             NaN
# 3               625.056523   4.10.0+multicore+redzone0             NaN
# 3               625.056523  4.10.0+multicore+redzone32             NaN
# 3               581.325540            4.10.0+multicore             NaN
# 3                      NaN                4.10.0+stock             1.0
# 40              236.335208   4.10.0+multicore+redzone0             NaN
# 40              236.347377            4.10.0+multicore             NaN
# 40              236.335208  4.10.0+multicore+redzone32             NaN
# 41                     NaN                4.10.0+stock             1.0
# 9                84.403253            4.10.0+multicore             NaN
# 9                      NaN                4.10.0+stock            10.0
# 9                84.402694  4.10.0+multicore+redzone32             NaN
# 9                84.402694   4.10.0+multicore+redzone0             NaN
# 7                      NaN                4.10.0+stock             3.0
# 7               110.704032  4.10.0+multicore+redzone32             NaN
# 7               110.704032   4.10.0+multicore+redzone0             NaN
# 7               110.704720            4.10.0+multicore             NaN
# 47                     NaN                4.10.0+stock             2.0
# 46              136.681705            4.10.0+multicore             NaN
# 46              136.679176   4.10.0+multicore+redzone0             NaN
# 46              136.679176  4.10.0+multicore+redzone32             NaN
# 20                     NaN                4.10.0+stock             4.0
# 20              117.754036   4.10.0+multicore+redzone0             NaN
# 20              117.754036  4.10.0+multicore+redzone32             NaN
# 20              117.754974            4.10.0+multicore             NaN
# 4                      NaN                4.10.0+stock             2.0
# 4               117.038549  4.10.0+multicore+redzone32             NaN
# 4               117.039733            4.10.0+multicore             NaN
# 4               117.038549   4.10.0+multicore+redzone0             NaN
# 39                     NaN                4.10.0+stock            16.0
# 38              105.279867            4.10.0+multicore             NaN
# 38              106.039717   4.10.0+multicore+redzone0             NaN
# 38              106.039717  4.10.0+multicore+redzone32             NaN
#
#     gc.compactions
# 10             NaN
# 10             0.0
# 10             NaN
# 10             NaN
# 22             NaN
# 22             0.0
# 22             NaN
# 22             NaN
# 12             0.0
# 12             NaN
# 12             NaN
# 12             NaN
# 34             NaN
# 34             NaN
# 34             NaN
# 34             0.0
# 41             NaN
# 41             NaN
# 42             0.0
# 41             NaN
# 33             2.0
# 33             NaN
# 33             NaN
# 33             NaN
# 48             0.0
# 47             NaN
# 47             NaN
# 47             NaN
# 6              NaN
# 6              NaN
# 6              NaN
# 6              0.0
# 32             NaN
# 32             NaN
# 32             NaN
# 32             0.0
# 37             NaN
# 37             NaN
# 38             0.0
# 37             NaN
# 43             NaN
# 44             0.0
# 43             NaN
# 43             NaN
# 8              NaN
# 8              NaN
# 8              0.0
# 8              NaN
# 42             NaN
# 42             NaN
# 42             NaN
# 43             0.0
# 25             NaN
# 25             NaN
# 25             NaN
# 25             0.0
# 27             NaN
# 27             NaN
# 27             2.0
# 27             NaN
# 15             NaN
# 15             NaN
# 15             0.0
# 15             NaN
# 30             0.0
# 30             NaN
# 30             NaN
# 30             NaN
# 29             NaN
# 29             NaN
# 29             0.0
# 29             NaN
# 53             NaN
# 53             NaN
# 53             NaN
# 54             0.0
# 23             NaN
# 23             0.0
# 23             NaN
# 23             NaN
# 2              0.0
# 2              NaN
# 2              NaN
# 2              NaN
# 16             0.0
# 16             NaN
# 16             NaN
# 16             NaN
# 37             0.0
# 11             NaN
# 11             NaN
# 11             0.0
# 11             NaN
# 14             NaN
# 14             0.0
# 14             NaN
# 14             NaN
# 17             NaN
# 17             0.0
# 17             NaN
# 17             NaN
# 39             NaN
# 39             NaN
# 39             NaN
# 40             0.0
# 45             NaN
# 45             NaN
# 45             NaN
# 46            21.0
# 35            15.0
# 35             NaN
# 35             NaN
# 35             NaN
# 52             NaN
# 53             0.0
# 52             NaN
# 52             NaN
# 31             NaN
# 31             NaN
# 31             0.0
# 31             NaN
# 0              NaN
# 0              NaN
# 0            615.0
# 0              NaN
# 26             NaN
# 26             NaN
# 26             0.0
# 26             NaN
# 19             NaN
# 19             NaN
# 19             NaN
# 19             0.0
# 21             NaN
# 21             0.0
# 21             NaN
# 21             NaN
# 36             NaN
# 36             0.0
# 36             NaN
# 36             NaN
# 1              NaN
# 1              NaN
# 1              NaN
# 1              0.0
# 50             NaN
# 50             NaN
# 51             0.0
# 50             NaN
# 44             NaN
# 44             NaN
# 44             NaN
# 45             0.0
# 49             NaN
# 50             2.0
# 49             NaN
# 49             NaN
# 28             0.0
# 28             NaN
# 28             NaN
# 28             NaN
# 49           896.0
# 48             NaN
# 48             NaN
# 48             NaN
# 24             NaN
# 24             NaN
# 24             0.0
# 24             NaN
# 18             0.0
# 18             NaN
# 18             NaN
# 18             NaN
# 13             NaN
# 13             NaN
# 13             0.0
# 13             NaN
# 5              NaN
# 5              NaN
# 5              NaN
# 5              0.0
# 51             NaN
# 51             NaN
# 52             2.0
# 51             NaN
# 3              NaN
# 3              NaN
# 3              NaN
# 3              2.0
# 40             NaN
# 40             NaN
# 40             NaN
# 41             0.0
# 9              NaN
# 9             64.0
# 9              NaN
# 9              NaN
# 7              0.0
# 7              NaN
# 7              NaN
# 7              NaN
# 47             0.0
# 46             NaN
# 46             NaN
# 46             NaN
# 20             0.0
# 20             NaN
# 20             NaN
# 20             NaN
# 4              5.0
# 4              NaN
# 4              NaN
# 4              NaN
# 39           214.0
# 38             NaN
# 38             NaN
# 38             NaN
#
# [217 rows x 28 columns]

# %% [markdown]
# ### Drop some benchmarks

# %%
df = df[(df.name != 'frama-c.slevel') &            #multicore version does not exist
        (df.name != 'js_of_ocaml.frama-c_byte')]   #multicore version does not exist
throughput_df = df
df
# Out:
#                                          name  \
# 10                      LU_decomposition.1024
# 10                      LU_decomposition.1024
# 10                      LU_decomposition.1024
# 10                      LU_decomposition.1024
# 22                          alt-ergo.fill.why
# 22                          alt-ergo.fill.why
# 22                          alt-ergo.fill.why
# 22                          alt-ergo.fill.why
# 12                          alt-ergo.yyll.why
# 12                          alt-ergo.yyll.why
# 12                          alt-ergo.yyll.why
# 12                          alt-ergo.yyll.why
# 34                                     bdd.26
# 34                                     bdd.26
# 34                                     bdd.26
# 34                                     bdd.26
# 41                            binarytrees5.21
# 41                            binarytrees5.21
# 42                            binarytrees5.21
# 41                            binarytrees5.21
# 33                 chameneos_redux_lwt.600000
# 33                 chameneos_redux_lwt.600000
# 33                 chameneos_redux_lwt.600000
# 33                 chameneos_redux_lwt.600000
# 48               coq.AbstractInterpretation.v
# 47               coq.AbstractInterpretation.v
# 47               coq.AbstractInterpretation.v
# 47               coq.AbstractInterpretation.v
# 6                           coq.BasicSyntax.v
# 6                           coq.BasicSyntax.v
# 6                           coq.BasicSyntax.v
# 6                           coq.BasicSyntax.v
# 32                             cpdf.blacktext
# 32                             cpdf.blacktext
# 32                             cpdf.blacktext
# 32                             cpdf.blacktext
# 37                                 cpdf.scale
# 37                                 cpdf.scale
# 38                                 cpdf.scale
# 37                                 cpdf.scale
# 43                               cpdf.squeeze
# 44                               cpdf.squeeze
# 43                               cpdf.squeeze
# 43                               cpdf.squeeze
# 8                        crout-decomposition.
# 8                        crout-decomposition.
# 8                        crout-decomposition.
# 8                        crout-decomposition.
# 42                     cubicle.german_pfs.cub
# 42                     cubicle.german_pfs.cub
# 42                     cubicle.german_pfs.cub
# 43                     cubicle.german_pfs.cub
# 25                   cubicle.szymanski_at.cub
# 25                   cubicle.szymanski_at.cub
# 25                   cubicle.szymanski_at.cub
# 25                   cubicle.szymanski_at.cub
# 27                      durand-kerner-aberth.
# 27                      durand-kerner-aberth.
# 27                      durand-kerner-aberth.
# 27                      durand-kerner-aberth.
# 15         evolutionary_algorithm.10000_10000
# 15         evolutionary_algorithm.10000_10000
# 15         evolutionary_algorithm.10000_10000
# 15         evolutionary_algorithm.10000_10000
# 30                           fannkuchredux.12
# 30                           fannkuchredux.12
# 30                           fannkuchredux.12
# 30                           fannkuchredux.12
# 29                          fannkuchredux2.12
# 29                          fannkuchredux2.12
# 29                          fannkuchredux2.12
# 29                          fannkuchredux2.12
# 53                          fasta3.25_000_000
# 53                          fasta3.25_000_000
# 53                          fasta3.25_000_000
# 54                          fasta3.25_000_000
# 23                          fasta6.25_000_000
# 23                          fasta6.25_000_000
# 23                          fasta6.25_000_000
# 23                          fasta6.25_000_000
# 2                                        fft.
# 2                                        fft.
# 2                                        fft.
# 2                                        fft.
# 16                         floyd_warshall.512
# 16                         floyd_warshall.512
# 16                         floyd_warshall.512
# 16                         floyd_warshall.512
# 11                           game_of_life.256
# 11                           game_of_life.256
# 11                           game_of_life.256
# 11                           game_of_life.256
# 14                                grammatrix.
# 14                                grammatrix.
# 14                                grammatrix.
# 14                                grammatrix.
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000
# 40  imrin_mem_rw.10_000_50_000_80_100_000_000
# 45                                        kb.
# 45                                        kb.
# 45                                        kb.
# 46                                        kb.
# 35                                 kb_no_exc.
# 35                                 kb_no_exc.
# 35                                 kb_no_exc.
# 35                                 kb_no_exc.
# 52                               knucleotide.
# 53                               knucleotide.
# 52                               knucleotide.
# 52                               knucleotide.
# 31                              knucleotide3.
# 31                              knucleotide3.
# 31                              knucleotide3.
# 31                              knucleotide3.
# 0                            levinson-durbin.
# 0                            levinson-durbin.
# 0                            levinson-durbin.
# 0                            levinson-durbin.
# 26                               lexifi-g2pp.
# 26                               lexifi-g2pp.
# 26                               lexifi-g2pp.
# 26                               lexifi-g2pp.
# 19                         mandelbrot6.16_000
# 19                         mandelbrot6.16_000
# 19                         mandelbrot6.16_000
# 19                         mandelbrot6.16_000
# 21                 matrix_multiplication.1024
# 21                 matrix_multiplication.1024
# 21                 matrix_multiplication.1024
# 21                 matrix_multiplication.1024
# 36                              menhir.ocamly
# 36                              menhir.ocamly
# 36                              menhir.ocamly
# 36                              menhir.ocamly
# 1                           menhir.sql-parser
# 1                           menhir.sql-parser
# 1                           menhir.sql-parser
# 1                           menhir.sql-parser
# 50                              menhir.sysver
# 50                              menhir.sysver
# 51                              menhir.sysver
# 50                              menhir.sysver
# 44                        minilight.roomfront
# 44                        minilight.roomfront
# 44                        minilight.roomfront
# 45                        minilight.roomfront
# 49                          naive-multilayer.
# 50                          naive-multilayer.
# 49                          naive-multilayer.
# 49                          naive-multilayer.
# 28                           nbody.50_000_000
# 28                           nbody.50_000_000
# 28                           nbody.50_000_000
# 28                           nbody.50_000_000
# 49                           pidigits5.10_000
# 48                           pidigits5.10_000
# 48                           pidigits5.10_000
# 48                           pidigits5.10_000
# 24                          qr-decomposition.
# 24                          qr-decomposition.
# 24                          qr-decomposition.
# 24                          qr-decomposition.
# 18                          quicksort.4000000
# 18                          quicksort.4000000
# 18                          quicksort.4000000
# 18                          quicksort.4000000
# 13                               regexredux2.
# 13                               regexredux2.
# 13                               regexredux2.
# 13                               regexredux2.
# 5                                   revcomp2.
# 5                                   revcomp2.
# 5                                   revcomp2.
# 5                                   revcomp2.
# 51                         sequence_cps.10000
# 51                         sequence_cps.10000
# 52                         sequence_cps.10000
# 51                         sequence_cps.10000
# 3               setrip.-enc_-rseed_1067894368
# 3               setrip.-enc_-rseed_1067894368
# 3               setrip.-enc_-rseed_1067894368
# 3               setrip.-enc_-rseed_1067894368
# 40                        spectralnorm2.5_500
# 40                        spectralnorm2.5_500
# 40                        spectralnorm2.5_500
# 41                        spectralnorm2.5_500
# 9                  test_decompress.64_524_288
# 9                  test_decompress.64_524_288
# 9                  test_decompress.64_524_288
# 9                  test_decompress.64_524_288
# 7                                test_lwt.200
# 7                                test_lwt.200
# 7                                test_lwt.200
# 7                                test_lwt.200
# 47                thread_ring_lwt_mvar.20_000
# 46                thread_ring_lwt_mvar.20_000
# 46                thread_ring_lwt_mvar.20_000
# 46                thread_ring_lwt_mvar.20_000
# 20              thread_ring_lwt_stream.20_000
# 20              thread_ring_lwt_stream.20_000
# 20              thread_ring_lwt_stream.20_000
# 20              thread_ring_lwt_stream.20_000
# 4                    yojson_ydump.sample.json
# 4                    yojson_ydump.sample.json
# 4                    yojson_ydump.sample.json
# 4                    yojson_ydump.sample.json
# 39                             zarith_pi.5000
# 38                             zarith_pi.5000
# 38                             zarith_pi.5000
# 38                             zarith_pi.5000
#
#                                               command   time_secs  \
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.532988
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.218466
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.531972
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.385071
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.566125
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.021685
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.593185
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.616023
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   17.532885
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   18.301929
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   18.339121
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   18.200624
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.582651
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.623276
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.572424
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.270421
# 41         taskset --cpu-list 5 ./binarytrees5.exe 21   12.296776
# 41         taskset --cpu-list 5 ./binarytrees5.exe 21   12.691259
# 42         taskset --cpu-list 5 ./binarytrees5.exe 21   11.725996
# 41         taskset --cpu-list 5 ./binarytrees5.exe 21   12.748200
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.084518
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.258255
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.259385
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.250527
# 48  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  293.342959
# 47  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  322.526510
# 47  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  323.478994
# 47  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  325.257178
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  111.984415
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  113.384733
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  110.976984
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  104.018834
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    3.997935
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    4.017149
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    3.999818
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    4.188315
# 37  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   14.219408
# 37  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   14.229265
# 38  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   13.766666
# 37  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   14.371217
# 43  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.626318
# 44  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.432945
# 43  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.630203
# 43  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.706276
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.378919
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.416446
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.327643
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.378068
# 42  taskset --cpu-list 5 cubicle benchmarks/cubicl...  271.583435
# 42  taskset --cpu-list 5 cubicle benchmarks/cubicl...  271.654957
# 42  taskset --cpu-list 5 cubicle benchmarks/cubicl...  272.682828
# 43  taskset --cpu-list 5 cubicle benchmarks/cubicl...  234.789072
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  570.779414
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  578.129767
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  581.848810
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  566.162048
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.145797
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.153606
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.138931
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.152575
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   71.845517
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   71.858201
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   68.461066
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   74.323333
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   78.609458
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   94.164035
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   98.387937
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   93.480126
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   95.489403
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   90.920677
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   87.460362
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   90.992310
# 53       taskset --cpu-list 5 ./fasta3.exe 25_000_000    8.464174
# 53       taskset --cpu-list 5 ./fasta3.exe 25_000_000    8.255948
# 53       taskset --cpu-list 5 ./fasta3.exe 25_000_000    8.287676
# 54       taskset --cpu-list 5 ./fasta3.exe 25_000_000    7.476167
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.341172
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.757025
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.870499
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.349594
# 2                      taskset --cpu-list 5 ./fft.exe    4.955272
# 2                      taskset --cpu-list 5 ./fft.exe    3.678841
# 2                      taskset --cpu-list 5 ./fft.exe    3.713123
# 2                      taskset --cpu-list 5 ./fft.exe    3.746694
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    4.553231
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    3.683866
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    3.653924
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    3.662433
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.519269
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.414043
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.558226
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.415595
# 14              taskset --cpu-list 5 ./grammatrix.exe   94.811698
# 14              taskset --cpu-list 5 ./grammatrix.exe   93.947041
# 14              taskset --cpu-list 5 ./grammatrix.exe   95.695882
# 14              taskset --cpu-list 5 ./grammatrix.exe   94.925338
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.144451
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    6.720169
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.182761
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.199571
# 39  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    8.246158
# 39  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    8.194800
# 39  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    8.185835
# 40  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.947550
# 45                      taskset --cpu-list 5 ./kb.exe    4.215579
# 45                      taskset --cpu-list 5 ./kb.exe    4.217915
# 45                      taskset --cpu-list 5 ./kb.exe    4.181545
# 46                      taskset --cpu-list 5 ./kb.exe    4.133245
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.584991
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.575357
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.626528
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.575042
# 52             taskset --cpu-list 5 ./knucleotide.exe   46.812605
# 53             taskset --cpu-list 5 ./knucleotide.exe   43.457097
# 52             taskset --cpu-list 5 ./knucleotide.exe   46.604469
# 52             taskset --cpu-list 5 ./knucleotide.exe   47.665617
# 31            taskset --cpu-list 5 ./knucleotide3.exe   47.484276
# 31            taskset --cpu-list 5 ./knucleotide3.exe   49.506311
# 31            taskset --cpu-list 5 ./knucleotide3.exe   45.305798
# 31            taskset --cpu-list 5 ./knucleotide3.exe   47.060356
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    2.984550
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    2.967338
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    2.888597
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    3.067796
# 26                    taskset --cpu-list 5 ./main.exe   17.342709
# 26                    taskset --cpu-list 5 ./main.exe   17.403823
# 26                    taskset --cpu-list 5 ./main.exe   17.185935
# 26                    taskset --cpu-list 5 ./main.exe   17.383595
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   41.977878
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   41.076731
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   41.203864
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   39.844158
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    8.484307
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    9.727537
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    8.934777
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    8.446212
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  259.400356
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  234.466711
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  259.275777
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  261.143221
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    7.327255
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    7.370447
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    7.262291
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    6.891414
# 50  taskset --cpu-list 5 menhir -v --table benchma...   87.406347
# 50  taskset --cpu-list 5 menhir -v --table benchma...   87.514693
# 51  taskset --cpu-list 5 menhir -v --table benchma...   83.834905
# 50  taskset --cpu-list 5 menhir -v --table benchma...   88.191317
# 44  taskset --cpu-list 5 minilight-ocaml benchmark...   23.157055
# 44  taskset --cpu-list 5 minilight-ocaml benchmark...   23.132667
# 44  taskset --cpu-list 5 minilight-ocaml benchmark...   23.130167
# 45  taskset --cpu-list 5 minilight-ocaml benchmark...   21.906600
# 49        taskset --cpu-list 5 ./naive_multilayer.exe    4.535113
# 50        taskset --cpu-list 5 ./naive_multilayer.exe    4.262039
# 49        taskset --cpu-list 5 ./naive_multilayer.exe    4.519197
# 49        taskset --cpu-list 5 ./naive_multilayer.exe    4.570641
# 28        taskset --cpu-list 5 ./nbody.exe 50_000_000    7.454929
# 28        taskset --cpu-list 5 ./nbody.exe 50_000_000    7.629726
# 28        taskset --cpu-list 5 ./nbody.exe 50_000_000    7.585259
# 28        taskset --cpu-list 5 ./nbody.exe 50_000_000    7.658816
# 49        taskset --cpu-list 5 ./pidigits5.exe 10_000    6.261566
# 48        taskset --cpu-list 5 ./pidigits5.exe 10_000    2.337219
# 48        taskset --cpu-list 5 ./pidigits5.exe 10_000    2.342454
# 48        taskset --cpu-list 5 ./pidigits5.exe 10_000    2.335723
# 24        taskset --cpu-list 5 ./qr_decomposition.exe    2.238775
# 24        taskset --cpu-list 5 ./qr_decomposition.exe    2.205298
# 24        taskset --cpu-list 5 ./qr_decomposition.exe    2.075974
# 24        taskset --cpu-list 5 ./qr_decomposition.exe    2.206652
# 18       taskset --cpu-list 5 ./quicksort.exe 4000000    2.794134
# 18       taskset --cpu-list 5 ./quicksort.exe 4000000    3.071453
# 18       taskset --cpu-list 5 ./quicksort.exe 4000000    3.233472
# 18       taskset --cpu-list 5 ./quicksort.exe 4000000    3.221767
# 13             taskset --cpu-list 5 ./regexredux2.exe   18.618700
# 13             taskset --cpu-list 5 ./regexredux2.exe   18.241336
# 13             taskset --cpu-list 5 ./regexredux2.exe   19.549511
# 13             taskset --cpu-list 5 ./regexredux2.exe   18.253844
# 5                 taskset --cpu-list 5 ./revcomp2.exe    3.047961
# 5                 taskset --cpu-list 5 ./revcomp2.exe    3.047968
# 5                 taskset --cpu-list 5 ./revcomp2.exe    3.055184
# 5                 taskset --cpu-list 5 ./revcomp2.exe    3.183821
# 51      taskset --cpu-list 5 ./sequence_cps.exe 10000    1.910457
# 51      taskset --cpu-list 5 ./sequence_cps.exe 10000    1.892806
# 52      taskset --cpu-list 5 ./sequence_cps.exe 10000    1.600767
# 51      taskset --cpu-list 5 ./sequence_cps.exe 10000    1.890164
# 3   taskset --cpu-list 5 setrip -enc -rseed 106789...    1.620393
# 3   taskset --cpu-list 5 setrip -enc -rseed 106789...    1.576670
# 3   taskset --cpu-list 5 setrip -enc -rseed 106789...    1.628520
# 3   taskset --cpu-list 5 setrip -enc -rseed 106789...    1.527823
# 40     taskset --cpu-list 5 ./spectralnorm2.exe 5_500    7.811888
# 40     taskset --cpu-list 5 ./spectralnorm2.exe 5_500    7.537976
# 40     taskset --cpu-list 5 ./spectralnorm2.exe 5_500    7.537537
# 41     taskset --cpu-list 5 ./spectralnorm2.exe 5_500    8.107790
# 9   taskset --cpu-list 5 ./test_decompress.exe 64 ...    4.253654
# 9   taskset --cpu-list 5 ./test_decompress.exe 64 ...    4.068778
# 9   taskset --cpu-list 5 ./test_decompress.exe 64 ...    4.231658
# 9   taskset --cpu-list 5 ./test_decompress.exe 64 ...    4.296637
# 7             taskset --cpu-list 5 ./test_lwt.exe 200   28.827723
# 7             taskset --cpu-list 5 ./test_lwt.exe 200   23.286454
# 7             taskset --cpu-list 5 ./test_lwt.exe 200   23.033881
# 7             taskset --cpu-list 5 ./test_lwt.exe 200   22.533769
# 47  taskset --cpu-list 5 ./thread_ring_lwt_mvar.ex...    3.342148
# 46  taskset --cpu-list 5 ./thread_ring_lwt_mvar.ex...    3.463112
# 46  taskset --cpu-list 5 ./thread_ring_lwt_mvar.ex...    3.499324
# 46  taskset --cpu-list 5 ./thread_ring_lwt_mvar.ex...    3.466957
# 20  taskset --cpu-list 5 ./thread_ring_lwt_stream....   11.261371
# 20  taskset --cpu-list 5 ./thread_ring_lwt_stream....   11.027932
# 20  taskset --cpu-list 5 ./thread_ring_lwt_stream....   11.183574
# 20  taskset --cpu-list 5 ./thread_ring_lwt_stream....   11.099015
# 4     taskset --cpu-list 5 ./ydump.exe -c sample.json    0.758916
# 4     taskset --cpu-list 5 ./ydump.exe -c sample.json    0.772634
# 4     taskset --cpu-list 5 ./ydump.exe -c sample.json    0.772098
# 4     taskset --cpu-list 5 ./ydump.exe -c sample.json    0.773514
# 39          taskset --cpu-list 5 ./zarith_pi.exe 5000    1.481425
# 38          taskset --cpu-list 5 ./zarith_pi.exe 5000    0.588280
# 38          taskset --cpu-list 5 ./zarith_pi.exe 5000    0.583206
# 38          taskset --cpu-list 5 ./zarith_pi.exe 5000    0.582913
#
#     user_time_secs  sys_time_secs  maxrss_kB   codesize  \
# 10        4.504697       0.028004      37996    66666.0
# 10        4.035983       0.003999      29668    51658.0
# 10        4.515655       0.015998      38056    66666.0
# 10        4.368755       0.015988      37916    75341.0
# 22        2.386005       0.179849     430244  2822317.0
# 22        1.841239       0.180121     357088  2449386.0
# 22        2.364822       0.228079     430320  2822221.0
# 22        2.415792       0.199982     430324  2950783.0
# 12       17.398430       0.133970     283028  2449386.0
# 12       18.133526       0.168014     302972  2822317.0
# 12       18.226661       0.112016     302812  2950783.0
# 12       18.083205       0.116928     302848  2822221.0
# 34        5.574324       0.008003      22420   161020.0
# 34        5.598976       0.023995      22324   161020.0
# 34        5.560136       0.012000      22352   174360.0
# 34        5.262081       0.007997      21548   136950.0
https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 42  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 42  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 42  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 43  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 25  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 25  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 25  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 25  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 27  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 27  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 27  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 27  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 15  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 15  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 15  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 15  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 30  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 30  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 30  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 30  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 29  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 29  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 29  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 29  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 53  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 53  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 53  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 54  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 23  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 23  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 23  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 23  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 2   https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 2   https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 2   https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 2   https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 16  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 16  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 16  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 16  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 11  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 11  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 11  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 11  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 14  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 14  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 14  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 14  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 17  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 17  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 17  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 17  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 39  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 39  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 39  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 40  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 45  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 45  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 45  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 46  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 35  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 35  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 35  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 35  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 52  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 53  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 52  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 52  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 31  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 31  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 31  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 31  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 0   https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 0   https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 0   https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 0   https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 26  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 26  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# ...
# 15                     NaN                4.10.0+stock            54.0
# 15               14.011463   4.10.0+multicore+redzone0             NaN
# 30                     NaN                4.10.0+stock             1.0
# 30                0.000000  4.10.0+multicore+redzone32             NaN
# 30                0.000000   4.10.0+multicore+redzone0             NaN
# 30                0.000000            4.10.0+multicore             NaN
# 29                0.000000   4.10.0+multicore+redzone0             NaN
# 29                0.000000            4.10.0+multicore             NaN
# 29                     NaN                4.10.0+stock             1.0
# 29                0.000000  4.10.0+multicore+redzone32             NaN
# 53                0.000000   4.10.0+multicore+redzone0             NaN
# 53                0.000000  4.10.0+multicore+redzone32             NaN
# 53                0.000000            4.10.0+multicore             NaN
# 54                     NaN                4.10.0+stock             1.0
# 23                0.638682  4.10.0+multicore+redzone32             NaN
# 23                     NaN                4.10.0+stock             3.0
# 23                0.638693   4.10.0+multicore+redzone0             NaN
# 23                0.595731            4.10.0+multicore             NaN
# 2                      NaN                4.10.0+stock            18.0
# 2                35.104247   4.10.0+multicore+redzone0             NaN
# 2                35.104247  4.10.0+multicore+redzone32             NaN
# 2                35.104264            4.10.0+multicore             NaN
# 16                     NaN                4.10.0+stock            15.0
# 16               38.481655   4.10.0+multicore+redzone0             NaN
# 16               38.481926            4.10.0+multicore             NaN
# 16               38.481655  4.10.0+multicore+redzone32             NaN
# 11                8.249132   4.10.0+multicore+redzone0             NaN
# 11                8.249132  4.10.0+multicore+redzone32             NaN
# 11                     NaN                4.10.0+stock            18.0
# 11                8.249411            4.10.0+multicore             NaN
# 14                4.810851            4.10.0+multicore             NaN
# 14                     NaN                4.10.0+stock            42.0
# 14                4.705581   4.10.0+multicore+redzone0             NaN
# 14                4.705581  4.10.0+multicore+redzone32             NaN
# 17              110.322628  4.10.0+multicore+redzone32             NaN
# 17                     NaN                4.10.0+stock             7.0
# 17              110.324694            4.10.0+multicore             NaN
# 17              110.322628   4.10.0+multicore+redzone0             NaN
# 39              110.369536   4.10.0+multicore+redzone0             NaN
# 39              110.371604            4.10.0+multicore             NaN
# 39              110.369536  4.10.0+multicore+redzone32             NaN
# 40                     NaN                4.10.0+stock             7.0
# 45               84.854569            4.10.0+multicore             NaN
# 45               78.637302  4.10.0+multicore+redzone32             NaN
# 45               78.638287   4.10.0+multicore+redzone0             NaN
# 46                     NaN                4.10.0+stock             7.0
# 35                     NaN                4.10.0+stock             8.0
# 35               79.476181  4.10.0+multicore+redzone32             NaN
# 35               79.476181   4.10.0+multicore+redzone0             NaN
# 35               79.477052            4.10.0+multicore             NaN
# 52               12.719830            4.10.0+multicore             NaN
# 53                     NaN                4.10.0+stock            11.0
# 52               12.719692  4.10.0+multicore+redzone32             NaN
# 52               12.719692   4.10.0+multicore+redzone0             NaN
# 31             2610.910590   4.10.0+multicore+redzone0             NaN
# 31             2610.910590  4.10.0+multicore+redzone32             NaN
# 31                     NaN                4.10.0+stock             3.0
# 31             2613.889413            4.10.0+multicore             NaN
# 0                94.658831  4.10.0+multicore+redzone32             NaN
# 0                94.637929            4.10.0+multicore             NaN
# 0                      NaN                4.10.0+stock             2.0
# 0                94.658831   4.10.0+multicore+redzone0             NaN
# 26               92.490934  4.10.0+multicore+redzone32             NaN
# 26               92.490934   4.10.0+multicore+redzone0             NaN
# 26                     NaN                4.10.0+stock             1.0
# 26               92.493740            4.10.0+multicore             NaN
# 19                0.000000            4.10.0+multicore             NaN
# 19                0.000000   4.10.0+multicore+redzone0             NaN
# 19                0.000000  4.10.0+multicore+redzone32             NaN
# 19                     NaN                4.10.0+stock             1.0
# 21                6.965498            4.10.0+multicore             NaN
# 21                     NaN                4.10.0+stock            21.0
# 21                6.965288  4.10.0+multicore+redzone32             NaN
# 21                6.965288   4.10.0+multicore+redzone0             NaN
# 36               22.686568            4.10.0+multicore             NaN
# 36                     NaN                4.10.0+stock            50.0
# 36               22.686503   4.10.0+multicore+redzone0             NaN
# 36               22.686503  4.10.0+multicore+redzone32             NaN
# 1                15.144751  4.10.0+multicore+redzone32             NaN
# 1                15.144751   4.10.0+multicore+redzone0             NaN
# 1                15.144822            4.10.0+multicore             NaN
# 1                      NaN                4.10.0+stock            38.0
# 50               30.990187   4.10.0+multicore+redzone0             NaN
# 50               30.676174            4.10.0+multicore             NaN
# 51                     NaN                4.10.0+stock            43.0
# 50               30.990187  4.10.0+multicore+redzone32             NaN
# 44               48.736418   4.10.0+multicore+redzone0             NaN
# 44               48.840422            4.10.0+multicore             NaN
# 44               48.736418  4.10.0+multicore+redzone32             NaN
# 45                     NaN                4.10.0+stock            10.0
# 49              214.409547            4.10.0+multicore             NaN
# 50                     NaN                4.10.0+stock             1.0
# 49              214.396195  4.10.0+multicore+redzone32             NaN
# 49              214.396195   4.10.0+multicore+redzone0             NaN
# 28                     NaN                4.10.0+stock             1.0
# 28                0.000000   4.10.0+multicore+redzone0             NaN
# 28                0.000000            4.10.0+multicore             NaN
# 28                0.000000  4.10.0+multicore+redzone32             NaN
# 49                     NaN                4.10.0+stock            17.0
# 48              104.431343   4.10.0+multicore+redzone0             NaN
# 48              104.431701            4.10.0+multicore             NaN
# 48              104.431343  4.10.0+multicore+redzone32             NaN
# 24               67.405752   4.10.0+multicore+redzone0             NaN
# 24               67.405752  4.10.0+multicore+redzone32             NaN
# 24                     NaN                4.10.0+stock             3.0
# 24               67.403944            4.10.0+multicore             NaN
# 18                     NaN                4.10.0+stock             2.0
# 18                0.000000   4.10.0+multicore+redzone0             NaN
# 18                0.000000  4.10.0+multicore+redzone32             NaN
# 18                0.000000            4.10.0+multicore             NaN
# 13               20.282913   4.10.0+multicore+redzone0             NaN
# 13               20.282931            4.10.0+multicore             NaN
# 13                     NaN                4.10.0+stock            16.0
# 13               20.282913  4.10.0+multicore+redzone32             NaN
# 5                23.104556            4.10.0+multicore             NaN
# 5                23.104471  4.10.0+multicore+redzone32             NaN
# 5                23.104471   4.10.0+multicore+redzone0             NaN
# 5                      NaN                4.10.0+stock            35.0
# 51             5175.202114   4.10.0+multicore+redzone0             NaN
# 51             5166.673713  4.10.0+multicore+redzone32             NaN
# 52                     NaN                4.10.0+stock             1.0
# 51             5183.758343            4.10.0+multicore             NaN
# 3               625.056523   4.10.0+multicore+redzone0             NaN
# 3               625.056523  4.10.0+multicore+redzone32             NaN
# 3               581.325540            4.10.0+multicore             NaN
# 3                      NaN                4.10.0+stock             1.0
# 40              236.335208   4.10.0+multicore+redzone0             NaN
# 40              236.347377            4.10.0+multicore             NaN
# 40              236.335208  4.10.0+multicore+redzone32             NaN
# 41                     NaN                4.10.0+stock             1.0
# 9                84.403253            4.10.0+multicore             NaN
# 9                      NaN                4.10.0+stock            10.0
# 9                84.402694  4.10.0+multicore+redzone32             NaN
# 9                84.402694   4.10.0+multicore+redzone0             NaN
# 7                      NaN                4.10.0+stock             3.0
# 7               110.704032  4.10.0+multicore+redzone32             NaN
# 7               110.704032   4.10.0+multicore+redzone0             NaN
# 7               110.704720            4.10.0+multicore             NaN
# 47                     NaN                4.10.0+stock             2.0
# 46              136.681705            4.10.0+multicore             NaN
# 46              136.679176   4.10.0+multicore+redzone0             NaN
# 46              136.679176  4.10.0+multicore+redzone32             NaN
# 20                     NaN                4.10.0+stock             4.0
# 20              117.754036   4.10.0+multicore+redzone0             NaN
# 20              117.754036  4.10.0+multicore+redzone32             NaN
# 20              117.754974            4.10.0+multicore             NaN
# 4                      NaN                4.10.0+stock             2.0
# 4               117.038549  4.10.0+multicore+redzone32             NaN
# 4               117.039733            4.10.0+multicore             NaN
# 4               117.038549   4.10.0+multicore+redzone0             NaN
# 39                     NaN                4.10.0+stock            16.0
# 38              105.279867            4.10.0+multicore             NaN
# 38              106.039717   4.10.0+multicore+redzone0             NaN
# 38              106.039717  4.10.0+multicore+redzone32             NaN
#
#     gc.compactions
# 10             NaN
# 10             0.0
# 10             NaN
# 10             NaN
# 22             NaN
# 22             0.0
# 22             NaN
# 22             NaN
# 12             0.0
# 12             NaN
# 12             NaN
# 12             NaN
# 34             NaN
# 34             NaN
# 34             NaN
# 34             0.0
# 41             NaN
# 41             NaN
# 42             0.0
# 41             NaN
# 33             2.0
# 33             NaN
# 33             NaN
# 33             NaN
# 48             0.0
# 47             NaN
# 47             NaN
# 47             NaN
# 6              NaN
# 6              NaN
# 6              NaN
# 6              0.0
# 32             NaN
# 32             NaN
# 32             NaN
# 32             0.0
# 37             NaN
# 37             NaN
# 38             0.0
# 37             NaN
# 43             NaN
# 44             0.0
# 43             NaN
# 43             NaN
# 8              NaN
# 8              NaN
# 8              0.0
# 8              NaN
# 42             NaN
# 42             NaN
# 42             NaN
# 43             0.0
# 25             NaN
# 25             NaN
# 25             NaN
# 25             0.0
# 27             NaN
# 27             NaN
# 27             2.0
# 27             NaN
# 15             NaN
# 15             NaN
# 15             0.0
# 15             NaN
# 30             0.0
# 30             NaN
# 30             NaN
# 30             NaN
# 29             NaN
# 29             NaN
# 29             0.0
# 29             NaN
# 53             NaN
# 53             NaN
# 53             NaN
# 54             0.0
# 23             NaN
# 23             0.0
# 23             NaN
# 23             NaN
# 2              0.0
# 2              NaN
# 2              NaN
# 2              NaN
# 16             0.0
# 16             NaN
# 16             NaN
# 16             NaN
# 11             NaN
# 11             NaN
# 11             0.0
# 11             NaN
# 14             NaN
# 14             0.0
# 14             NaN
# 14             NaN
# 17             NaN
# 17             0.0
# 17             NaN
# 17             NaN
# 39             NaN
# 39             NaN
# 39             NaN
# 40             0.0
# 45             NaN
# 45             NaN
# 45             NaN
# 46            21.0
# 35            15.0
# 35             NaN
# 35             NaN
# 35             NaN
# 52             NaN
# 53             0.0
# 52             NaN
# 52             NaN
# 31             NaN
# 31             NaN
# 31             0.0
# 31             NaN
# 0              NaN
# 0              NaN
# 0            615.0
# 0              NaN
# 26             NaN
# 26             NaN
# 26             0.0
# 26             NaN
# 19             NaN
# 19             NaN
# 19             NaN
# 19             0.0
# 21             NaN
# 21             0.0
# 21             NaN
# 21             NaN
# 36             NaN
# 36             0.0
# 36             NaN
# 36             NaN
# 1              NaN
# 1              NaN
# 1              NaN
# 1              0.0
# 50             NaN
# 50             NaN
# 51             0.0
# 50             NaN
# 44             NaN
# 44             NaN
# 44             NaN
# 45             0.0
# 49             NaN
# 50             2.0
# 49             NaN
# 49             NaN
# 28             0.0
# 28             NaN
# 28             NaN
# 28             NaN
# 49           896.0
# 48             NaN
# 48             NaN
# 48             NaN
# 24             NaN
# 24             NaN
# 24             0.0
# 24             NaN
# 18             0.0
# 18             NaN
# 18             NaN
# 18             NaN
# 13             NaN
# 13             NaN
# 13             0.0
# 13             NaN
# 5              NaN
# 5              NaN
# 5              NaN
# 5              0.0
# 51             NaN
# 51             NaN
# 52             2.0
# 51             NaN
# 3              NaN
# 3              NaN
# 3              NaN
# 3              2.0
# 40             NaN
# 40             NaN
# 40             NaN
# 41             0.0
# 9              NaN
# 9             64.0
# 9              NaN
# 9              NaN
# 7              0.0
# 7              NaN
# 7              NaN
# 7              NaN
# 47             0.0
# 46             NaN
# 46             NaN
# 46             NaN
# 20             0.0
# 20             NaN
# 20             NaN
# 20             NaN
# 4              5.0
# 4              NaN
# 4              NaN
# 4              NaN
# 39           214.0
# 38             NaN
# 38             NaN
# 38             NaN
#
# [216 rows x 28 columns]

# %% [markdown]
# ## Rename

# %%
def remapVariant(v):
    if (v.startswith('4.10.0+multicore+redzone32')):
        return 'MC+RedZone32'
    elif (v.startswith('4.10.0+multicore+redzone0')):
        return 'MC+RedZone0'
    elif (v.startswith('4.10.0+multicore')):
        return 'MC'
    elif (v.startswith('4.10.0+stock')):
        return 'Stock'
    else:
        return v
    
def sanitizeVariant(df):
    df['variant'] = df['variant'].apply(remapVariant)

sanitizeVariant(df)
# Out:
# <ipython-input-101-527d8eee75b3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['variant'] = df['variant'].apply(remapVariant)

# %%
df
# Out:
#                                          name  \
# 10                      LU_decomposition.1024
# 10                      LU_decomposition.1024
# 10                      LU_decomposition.1024
# 10                      LU_decomposition.1024
# 22                          alt-ergo.fill.why
# 22                          alt-ergo.fill.why
# 22                          alt-ergo.fill.why
# 22                          alt-ergo.fill.why
# 12                          alt-ergo.yyll.why
# 12                          alt-ergo.yyll.why
# 12                          alt-ergo.yyll.why
# 12                          alt-ergo.yyll.why
# 34                                     bdd.26
# 34                                     bdd.26
# 34                                     bdd.26
# 34                                     bdd.26
# 41                            binarytrees5.21
# 41                            binarytrees5.21
# 42                            binarytrees5.21
# 41                            binarytrees5.21
# 33                 chameneos_redux_lwt.600000
# 33                 chameneos_redux_lwt.600000
# 33                 chameneos_redux_lwt.600000
# 33                 chameneos_redux_lwt.600000
# 48               coq.AbstractInterpretation.v
# 47               coq.AbstractInterpretation.v
# 47               coq.AbstractInterpretation.v
# 47               coq.AbstractInterpretation.v
# 6                           coq.BasicSyntax.v
# 6                           coq.BasicSyntax.v
# 6                           coq.BasicSyntax.v
# 6                           coq.BasicSyntax.v
# 32                             cpdf.blacktext
# 32                             cpdf.blacktext
# 32                             cpdf.blacktext
# 32                             cpdf.blacktext
# 37                                 cpdf.scale
# 37                                 cpdf.scale
# 38                                 cpdf.scale
# 37                                 cpdf.scale
# 43                               cpdf.squeeze
# 44                               cpdf.squeeze
# 43                               cpdf.squeeze
# 43                               cpdf.squeeze
# 8                        crout-decomposition.
# 8                        crout-decomposition.
# 8                        crout-decomposition.
# 8                        crout-decomposition.
# 42                     cubicle.german_pfs.cub
# 42                     cubicle.german_pfs.cub
# 42                     cubicle.german_pfs.cub
# 43                     cubicle.german_pfs.cub
# 25                   cubicle.szymanski_at.cub
# 25                   cubicle.szymanski_at.cub
# 25                   cubicle.szymanski_at.cub
# 25                   cubicle.szymanski_at.cub
# 27                      durand-kerner-aberth.
# 27                      durand-kerner-aberth.
# 27                      durand-kerner-aberth.
# 27                      durand-kerner-aberth.
# 15         evolutionary_algorithm.10000_10000
# 15         evolutionary_algorithm.10000_10000
# 15         evolutionary_algorithm.10000_10000
# 15         evolutionary_algorithm.10000_10000
# 30                           fannkuchredux.12
# 30                           fannkuchredux.12
# 30                           fannkuchredux.12
# 30                           fannkuchredux.12
# 29                          fannkuchredux2.12
# 29                          fannkuchredux2.12
# 29                          fannkuchredux2.12
# 29                          fannkuchredux2.12
# 53                          fasta3.25_000_000
# 53                          fasta3.25_000_000
# 53                          fasta3.25_000_000
# 54                          fasta3.25_000_000
# 23                          fasta6.25_000_000
# 23                          fasta6.25_000_000
# 23                          fasta6.25_000_000
# 23                          fasta6.25_000_000
# 2                                        fft.
# 2                                        fft.
# 2                                        fft.
# 2                                        fft.
# 16                         floyd_warshall.512
# 16                         floyd_warshall.512
# 16                         floyd_warshall.512
# 16                         floyd_warshall.512
# 11                           game_of_life.256
# 11                           game_of_life.256
# 11                           game_of_life.256
# 11                           game_of_life.256
# 14                                grammatrix.
# 14                                grammatrix.
# 14                                grammatrix.
# 14                                grammatrix.
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000
# 40  imrin_mem_rw.10_000_50_000_80_100_000_000
# 45                                        kb.
# 45                                        kb.
# 45                                        kb.
# 46                                        kb.
# 35                                 kb_no_exc.
# 35                                 kb_no_exc.
# 35                                 kb_no_exc.
# 35                                 kb_no_exc.
# 52                               knucleotide.
# 53                               knucleotide.
# 52                               knucleotide.
# 52                               knucleotide.
# 31                              knucleotide3.
# 31                              knucleotide3.
# 31                              knucleotide3.
# 31                              knucleotide3.
# 0                            levinson-durbin.
# 0                            levinson-durbin.
# 0                            levinson-durbin.
# 0                            levinson-durbin.
# 26                               lexifi-g2pp.
# 26                               lexifi-g2pp.
# 26                               lexifi-g2pp.
# 26                               lexifi-g2pp.
# 19                         mandelbrot6.16_000
# 19                         mandelbrot6.16_000
# 19                         mandelbrot6.16_000
# 19                         mandelbrot6.16_000
# 21                 matrix_multiplication.1024
# 21                 matrix_multiplication.1024
# 21                 matrix_multiplication.1024
# 21                 matrix_multiplication.1024
# 36                              menhir.ocamly
# 36                              menhir.ocamly
# 36                              menhir.ocamly
# 36                              menhir.ocamly
# 1                           menhir.sql-parser
# 1                           menhir.sql-parser
# 1                           menhir.sql-parser
# 1                           menhir.sql-parser
# 50                              menhir.sysver
# 50                              menhir.sysver
# 51                              menhir.sysver
# 50                              menhir.sysver
# 44                        minilight.roomfront
# 44                        minilight.roomfront
# 44                        minilight.roomfront
# 45                        minilight.roomfront
# 49                          naive-multilayer.
# 50                          naive-multilayer.
# 49                          naive-multilayer.
# 49                          naive-multilayer.
# 28                           nbody.50_000_000
# 28                           nbody.50_000_000
# 28                           nbody.50_000_000
# 28                           nbody.50_000_000
# 49                           pidigits5.10_000
# 48                           pidigits5.10_000
# 48                           pidigits5.10_000
# 48                           pidigits5.10_000
# 24                          qr-decomposition.
# 24                          qr-decomposition.
# 24                          qr-decomposition.
# 24                          qr-decomposition.
# 18                          quicksort.4000000
# 18                          quicksort.4000000
# 18                          quicksort.4000000
# 18                          quicksort.4000000
# 13                               regexredux2.
# 13                               regexredux2.
# 13                               regexredux2.
# 13                               regexredux2.
# 5                                   revcomp2.
# 5                                   revcomp2.
# 5                                   revcomp2.
# 5                                   revcomp2.
# 51                         sequence_cps.10000
# 51                         sequence_cps.10000
# 52                         sequence_cps.10000
# 51                         sequence_cps.10000
# 3               setrip.-enc_-rseed_1067894368
# 3               setrip.-enc_-rseed_1067894368
# 3               setrip.-enc_-rseed_1067894368
# 3               setrip.-enc_-rseed_1067894368
# 40                        spectralnorm2.5_500
# 40                        spectralnorm2.5_500
# 40                        spectralnorm2.5_500
# 41                        spectralnorm2.5_500
# 9                  test_decompress.64_524_288
# 9                  test_decompress.64_524_288
# 9                  test_decompress.64_524_288
# 9                  test_decompress.64_524_288
# 7                                test_lwt.200
# 7                                test_lwt.200
# 7                                test_lwt.200
# 7                                test_lwt.200
# 47                thread_ring_lwt_mvar.20_000
# 46                thread_ring_lwt_mvar.20_000
# 46                thread_ring_lwt_mvar.20_000
# 46                thread_ring_lwt_mvar.20_000
# 20              thread_ring_lwt_stream.20_000
# 20              thread_ring_lwt_stream.20_000
# 20              thread_ring_lwt_stream.20_000
# 20              thread_ring_lwt_stream.20_000
# 4                    yojson_ydump.sample.json
# 4                    yojson_ydump.sample.json
# 4                    yojson_ydump.sample.json
# 4                    yojson_ydump.sample.json
# 39                             zarith_pi.5000
# 38                             zarith_pi.5000
# 38                             zarith_pi.5000
# 38                             zarith_pi.5000
#
#                                               command   time_secs  \
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.532988
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.218466
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.531972
# 10   taskset --cpu-list 5 ./LU_decomposition.exe 1024    4.385071
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.566125
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.021685
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.593185
# 22  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...    2.616023
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   17.532885
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   18.301929
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   18.339121
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   18.200624
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.582651
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.623276
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.572424
# 34                  taskset --cpu-list 5 ./bdd.exe 26    5.270421
# 41         taskset --cpu-list 5 ./binarytrees5.exe 21   12.296776
# 41         taskset --cpu-list 5 ./binarytrees5.exe 21   12.691259
# 42         taskset --cpu-list 5 ./binarytrees5.exe 21   11.725996
# 41         taskset --cpu-list 5 ./binarytrees5.exe 21   12.748200
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.084518
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.258255
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.259385
# 33  taskset --cpu-list 5 ./chameneos_redux_lwt.exe...    2.250527
# 48  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  293.342959
# 47  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  322.526510
# 47  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  323.478994
# 47  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  325.257178
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  111.984415
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  113.384733
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  110.976984
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  104.018834
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    3.997935
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    4.017149
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    3.999818
# 32  taskset --cpu-list 5 cpdf -blacktext benchmark...    4.188315
# 37  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   14.219408
# 37  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   14.229265
# 38  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   13.766666
# 37  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   14.371217
# 43  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.626318
# 44  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.432945
# 43  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.630203
# 43  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.706276
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.378919
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.416446
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.327643
# 8      taskset --cpu-list 5 ./crout_decomposition.exe    1.378068
# 42  taskset --cpu-list 5 cubicle benchmarks/cubicl...  271.583435
# 42  taskset --cpu-list 5 cubicle benchmarks/cubicl...  271.654957
# 42  taskset --cpu-list 5 cubicle benchmarks/cubicl...  272.682828
# 43  taskset --cpu-list 5 cubicle benchmarks/cubicl...  234.789072
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  570.779414
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  578.129767
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  581.848810
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  566.162048
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.145797
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.153606
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.138931
# 27    taskset --cpu-list 5 ./durand_kerner_aberth.exe    0.152575
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   71.845517
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   71.858201
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   68.461066
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   74.323333
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   78.609458
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   94.164035
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   98.387937
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   93.480126
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   95.489403
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   90.920677
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   87.460362
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   90.992310
# 53       taskset --cpu-list 5 ./fasta3.exe 25_000_000    8.464174
# 53       taskset --cpu-list 5 ./fasta3.exe 25_000_000    8.255948
# 53       taskset --cpu-list 5 ./fasta3.exe 25_000_000    8.287676
# 54       taskset --cpu-list 5 ./fasta3.exe 25_000_000    7.476167
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.341172
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.757025
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.870499
# 23       taskset --cpu-list 5 ./fasta6.exe 25_000_000    5.349594
# 2                      taskset --cpu-list 5 ./fft.exe    4.955272
# 2                      taskset --cpu-list 5 ./fft.exe    3.678841
# 2                      taskset --cpu-list 5 ./fft.exe    3.713123
# 2                      taskset --cpu-list 5 ./fft.exe    3.746694
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    4.553231
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    3.683866
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    3.653924
# 16      taskset --cpu-list 5 ./floyd_warshall.exe 512    3.662433
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.519269
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.414043
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.558226
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.415595
# 14              taskset --cpu-list 5 ./grammatrix.exe   94.811698
# 14              taskset --cpu-list 5 ./grammatrix.exe   93.947041
# 14              taskset --cpu-list 5 ./grammatrix.exe   95.695882
# 14              taskset --cpu-list 5 ./grammatrix.exe   94.925338
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.144451
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    6.720169
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.182761
# 17  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.199571
# 39  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    8.246158
# 39  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    8.194800
# 39  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    8.185835
# 40  taskset --cpu-list 5 ./irmin_mem_rw.exe 10_000...    7.947550
# 45                      taskset --cpu-list 5 ./kb.exe    4.215579
# 45                      taskset --cpu-list 5 ./kb.exe    4.217915
# 45                      taskset --cpu-list 5 ./kb.exe    4.181545
# 46                      taskset --cpu-list 5 ./kb.exe    4.133245
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.584991
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.575357
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.626528
# 35               taskset --cpu-list 5 ./kb_no_exc.exe    2.575042
# 52             taskset --cpu-list 5 ./knucleotide.exe   46.812605
# 53             taskset --cpu-list 5 ./knucleotide.exe   43.457097
# 52             taskset --cpu-list 5 ./knucleotide.exe   46.604469
# 52             taskset --cpu-list 5 ./knucleotide.exe   47.665617
# 31            taskset --cpu-list 5 ./knucleotide3.exe   47.484276
# 31            taskset --cpu-list 5 ./knucleotide3.exe   49.506311
# 31            taskset --cpu-list 5 ./knucleotide3.exe   45.305798
# 31            taskset --cpu-list 5 ./knucleotide3.exe   47.060356
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    2.984550
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    2.967338
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    2.888597
# 0          taskset --cpu-list 5 ./levinson_durbin.exe    3.067796
# 26                    taskset --cpu-list 5 ./main.exe   17.342709
# 26                    taskset --cpu-list 5 ./main.exe   17.403823
# 26                    taskset --cpu-list 5 ./main.exe   17.185935
# 26                    taskset --cpu-list 5 ./main.exe   17.383595
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   41.977878
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   41.076731
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   41.203864
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   39.844158
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    8.484307
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    9.727537
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    8.934777
# 21  taskset --cpu-list 5 ./matrix_multiplication.e...    8.446212
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  259.400356
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  234.466711
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  259.275777
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  261.143221
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    7.327255
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    7.370447
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    7.262291
# 1   taskset --cpu-list 5 menhir -v -t benchmarks/m...    6.891414
# 50  taskset --cpu-list 5 menhir -v --table benchma...   87.406347
# 50  taskset --cpu-list 5 menhir -v --table benchma...   87.514693
# 51  taskset --cpu-list 5 menhir -v --table benchma...   83.834905
# 50  taskset --cpu-list 5 menhir -v --table benchma...   88.191317
# 44  taskset --cpu-list 5 minilight-ocaml benchmark...   23.157055
# 44  taskset --cpu-list 5 minilight-ocaml benchmark...   23.132667
# 44  taskset --cpu-list 5 minilight-ocaml benchmark...   23.130167
# 45  taskset --cpu-list 5 minilight-ocaml benchmark...   21.906600
# 49        taskset --cpu-list 5 ./naive_multilayer.exe    4.535113
# 50        taskset --cpu-list 5 ./naive_multilayer.exe    4.262039
# 49        taskset --cpu-list 5 ./naive_multilayer.exe    4.519197
# 49        taskset --cpu-list 5 ./naive_multilayer.exe    4.570641
# 28        taskset --cpu-list 5 ./nbody.exe 50_000_000    7.454929
# 28        taskset --cpu-list 5 ./nbody.exe 50_000_000    7.629726
# 28        taskset --cpu-list 5 ./nbody.exe 50_000_000    7.585259
# 28        taskset --cpu-list 5 ./nbody.exe 50_000_000    7.658816
# 49        taskset --cpu-list 5 ./pidigits5.exe 10_000    6.261566
# 48        taskset --cpu-list 5 ./pidigits5.exe 10_000    2.337219
# 48        taskset --cpu-list 5 ./pidigits5.exe 10_000    2.342454
# 48        taskset --cpu-list 5 ./pidigits5.exe 10_000    2.335723
# 24        taskset --cpu-list 5 ./qr_decomposition.exe    2.238775
# 24        taskset --cpu-list 5 ./qr_decomposition.exe    2.205298
# 24        taskset --cpu-list 5 ./qr_decomposition.exe    2.075974
# 24        taskset --cpu-list 5 ./qr_decomposition.exe    2.206652
# 18       taskset --cpu-list 5 ./quicksort.exe 4000000    2.794134
# 18       taskset --cpu-list 5 ./quicksort.exe 4000000    3.071453
# 18       taskset --cpu-list 5 ./quicksort.exe 4000000    3.233472
# 18       taskset --cpu-list 5 ./quicksort.exe 4000000    3.221767
# 13             taskset --cpu-list 5 ./regexredux2.exe   18.618700
# 13             taskset --cpu-list 5 ./regexredux2.exe   18.241336
# 13             taskset --cpu-list 5 ./regexredux2.exe   19.549511
# 13             taskset --cpu-list 5 ./regexredux2.exe   18.253844
# 5                 taskset --cpu-list 5 ./revcomp2.exe    3.047961
# 5                 taskset --cpu-list 5 ./revcomp2.exe    3.047968
# 5                 taskset --cpu-list 5 ./revcomp2.exe    3.055184
# 5                 taskset --cpu-list 5 ./revcomp2.exe    3.183821
# 51      taskset --cpu-list 5 ./sequence_cps.exe 10000    1.910457
# 51      taskset --cpu-list 5 ./sequence_cps.exe 10000    1.892806
# 52      taskset --cpu-list 5 ./sequence_cps.exe 10000    1.600767
# 51      taskset --cpu-list 5 ./sequence_cps.exe 10000    1.890164
# 3   taskset --cpu-list 5 setrip -enc -rseed 106789...    1.620393
# 3   taskset --cpu-list 5 setrip -enc -rseed 106789...    1.576670
# 3   taskset --cpu-list 5 setrip -enc -rseed 106789...    1.628520
# 3   taskset --cpu-list 5 setrip -enc -rseed 106789...    1.527823
# 40     taskset --cpu-list 5 ./spectralnorm2.exe 5_500    7.811888
# 40     taskset --cpu-list 5 ./spectralnorm2.exe 5_500    7.537976
# 40     taskset --cpu-list 5 ./spectralnorm2.exe 5_500    7.537537
# 41     taskset --cpu-list 5 ./spectralnorm2.exe 5_500    8.107790
# 9   taskset --cpu-list 5 ./test_decompress.exe 64 ...    4.253654
# 9   taskset --cpu-list 5 ./test_decompress.exe 64 ...    4.068778
# 9   taskset --cpu-list 5 ./test_decompress.exe 64 ...    4.231658
# 9   taskset --cpu-list 5 ./test_decompress.exe 64 ...    4.296637
# 7             taskset --cpu-list 5 ./test_lwt.exe 200
# 6                37.566949   MC+RedZone0             NaN             NaN
# 6                37.544719            MC             NaN             NaN
# 6                      NaN         Stock            35.0             0.0
# 32               24.080626  MC+RedZone32             NaN             NaN
# 32               24.080626   MC+RedZone0             NaN             NaN
# 32               24.080768            MC             NaN             NaN
# 32                     NaN         Stock            21.0             0.0
# 37               27.537963  MC+RedZone32             NaN             NaN
# 37               27.537768            MC             NaN             NaN
# 38                     NaN         Stock            36.0             0.0
# 37               27.537963   MC+RedZone0             NaN             NaN
# 43               32.710926            MC             NaN             NaN
# 44                     NaN         Stock            38.0             0.0
# 43               32.710912  MC+RedZone32             NaN             NaN
# 43               32.710912   MC+RedZone0             NaN             NaN
# 8                10.186580            MC             NaN             NaN
# 8                10.186066   MC+RedZone0             NaN             NaN
# 8                      NaN         Stock            27.0             0.0
# 8                10.186066  MC+RedZone32             NaN             NaN
# 42              113.522717   MC+RedZone0             NaN             NaN
# 42              114.017301            MC             NaN             NaN
# 42              113.522717  MC+RedZone32             NaN             NaN
# 43                     NaN         Stock            32.0             0.0
# 25               86.302573   MC+RedZone0             NaN             NaN
# 25               87.252437            MC             NaN             NaN
# 25               86.302573  MC+RedZone32             NaN             NaN
# 25                     NaN         Stock            23.0             0.0
# 27              357.800630   MC+RedZone0             NaN             NaN
# 27              357.800630  MC+RedZone32             NaN             NaN
# 27                     NaN         Stock             1.0             2.0
# 27              357.800613            MC             NaN             NaN
# 15               14.006602            MC             NaN             NaN
# 15               14.027308  MC+RedZone32             NaN             NaN
# 15                     NaN         Stock            54.0             0.0
# 15               14.011463   MC+RedZone0             NaN             NaN
# 30                     NaN         Stock             1.0             0.0
# 30                0.000000  MC+RedZone32             NaN             NaN
# 30                0.000000   MC+RedZone0             NaN             NaN
# 30                0.000000            MC             NaN             NaN
# 29                0.000000   MC+RedZone0             NaN             NaN
# 29                0.000000            MC             NaN             NaN
# 29                     NaN         Stock             1.0             0.0
# 29                0.000000  MC+RedZone32             NaN             NaN
# 53                0.000000   MC+RedZone0             NaN             NaN
# 53                0.000000  MC+RedZone32             NaN             NaN
# 53                0.000000            MC             NaN             NaN
# 54                     NaN         Stock             1.0             0.0
# 23                0.638682  MC+RedZone32             NaN             NaN
# 23                     NaN         Stock             3.0             0.0
# 23                0.638693   MC+RedZone0             NaN             NaN
# 23                0.595731            MC             NaN             NaN
# 2                      NaN         Stock            18.0             0.0
# 2                35.104247   MC+RedZone0             NaN             NaN
# 2                35.104247  MC+RedZone32             NaN             NaN
# 2                35.104264            MC             NaN             NaN
# 16                     NaN         Stock            15.0             0.0
# 16               38.481655   MC+RedZone0             NaN             NaN
# 16               38.481926            MC             NaN             NaN
# 16               38.481655  MC+RedZone32             NaN             NaN
# 11                8.249132   MC+RedZone0             NaN             NaN
# 11                8.249132  MC+RedZone32             NaN             NaN
# 11                     NaN         Stock            18.0             0.0
# 11                8.249411            MC             NaN             NaN
# 14                4.810851            MC             NaN             NaN
# 14                     NaN         Stock            42.0             0.0
# 14                4.705581   MC+RedZone0             NaN             NaN
# 48              104.431343   MC+RedZone0             NaN             NaN
# 48              104.431701            MC             NaN             NaN
# 48              104.431343  MC+RedZone32             NaN             NaN
# 24               67.405752   MC+RedZone0             NaN             NaN
# 24               67.405752  MC+RedZone32             NaN             NaN
# 24                     NaN         Stock             3.0             0.0
# 24               67.403944            MC             NaN             NaN
# 18                     NaN         Stock             2.0             0.0
# 18                0.000000   MC+RedZone0             NaN             NaN
# 18                0.000000  MC+RedZone32             NaN             NaN
# 18                0.000000            MC             NaN             NaN
# 13               20.282913   MC+RedZone0             NaN             NaN
# 13               20.282931            MC             NaN             NaN
# 13                     NaN         Stock            16.0             0.0
# 13               20.282913  MC+RedZone32             NaN             NaN
# 5                23.104556            MC             NaN             NaN
# 5                23.104471  MC+RedZone32             NaN             NaN
# 5                23.104471   MC+RedZone0             NaN             NaN
# 5                      NaN         Stock            35.0             0.0
# 51             5175.202114   MC+RedZone0             NaN             NaN
# 51             5166.673713  MC+RedZone32             NaN             NaN
# 52                     NaN         Stock             1.0             2.0
# 51             5183.758343            MC             NaN             NaN
# 3               625.056523   MC+RedZone0             NaN             NaN
# 3               625.056523  MC+RedZone32             NaN             NaN
# 3               581.325540            MC             NaN             NaN
# 3                      NaN         Stock             1.0             2.0
# 40              236.335208   MC+RedZone0             NaN             NaN
# 40              236.347377            MC             NaN             NaN
# 40              236.335208  MC+RedZone32             NaN             NaN
# 41                     NaN         Stock             1.0             0.0
# 9                84.403253            MC             NaN             NaN
# 9                      NaN         Stock            10.0            64.0
# 9                84.402694  MC+RedZone32             NaN             NaN
# 9                84.402694   MC+RedZone0             NaN             NaN
# 7                      NaN         Stock             3.0             0.0
# 7               110.704032  MC+RedZone32             NaN             NaN
# 7               110.704032   MC+RedZone0             NaN             NaN
# 7               110.704720            MC             NaN             NaN
# 47                     NaN         Stock             2.0             0.0
# 46              136.681705            MC             NaN             NaN
# 46              136.679176   MC+RedZone0             NaN             NaN
# 46              136.679176  MC+RedZone32             NaN             NaN
# 20                     NaN         Stock             4.0             0.0
# 20              117.754036   MC+RedZone0             NaN             NaN
# 20              117.754036  MC+RedZone32             NaN             NaN
# 20              117.754974            MC             NaN             NaN
# 4                      NaN         Stock             2.0             5.0
# 4               117.038549  MC+RedZone32             NaN             NaN
# 4               117.039733            MC             NaN             NaN
# 4               117.038549   MC+RedZone0             NaN             NaN
# 39                     NaN         Stock            16.0           214.0
# 38              105.279867            MC             NaN             NaN
# 38              106.039717   MC+RedZone0             NaN             NaN
# 38              106.039717  MC+RedZone32             NaN             NaN
#
# [216 rows x 28 columns]

# %% [markdown]
# ### Selection example
#
# ```
# select * from df where variant = '4.10.0+trunk' and time_secs > 10
# ```

# %%
df.loc[(df['variant'] == baseline) & (df['time_secs'] > 10)]
# Out:
#                                   name  \
# 12                   alt-ergo.yyll.why
# 42                     binarytrees5.21
# 48        coq.AbstractInterpretation.v
# 6                    coq.BasicSyntax.v
# 38                          cpdf.scale
# 44                        cpdf.squeeze
# 43              cubicle.german_pfs.cub
# 25            cubicle.szymanski_at.cub
# 15  evolutionary_algorithm.10000_10000
# 30                    fannkuchredux.12
# 29                   fannkuchredux2.12
# 11                    game_of_life.256
# 14                         grammatrix.
# 53                        knucleotide.
# 31                       knucleotide3.
# 26                        lexifi-g2pp.
# 19                  mandelbrot6.16_000
# 36                       menhir.ocamly
# 51                       menhir.sysver
# 45                 minilight.roomfront
# 13                        regexredux2.
# 7                         test_lwt.200
# 20       thread_ring_lwt_stream.20_000
#
#                                               command   time_secs  \
# 12  taskset --cpu-list 5 alt-ergo benchmarks/alt-e...   17.532885
# 42         taskset --cpu-list 5 ./binarytrees5.exe 21   11.725996
# 48  taskset --cpu-list 5 coqc benchmarks/coq/Abstr...  293.342959
# 6   taskset --cpu-list 5 coqc benchmarks/coq/Basic...  104.018834
# 38  taskset --cpu-list 5 cpdf scale-to-fit a4lands...   13.766666
# 44  taskset --cpu-list 5 cpdf -squeeze benchmarks/...   16.432945
# 43  taskset --cpu-list 5 cubicle benchmarks/cubicl...  234.789072
# 25  taskset --cpu-list 5 cubicle benchmarks/cubicl...  566.162048
# 15  taskset --cpu-list 5 ./evolutionary_algorithm....   68.461066
# 30        taskset --cpu-list 5 ./fannkuchredux.exe 12   78.609458
# 29       taskset --cpu-list 5 ./fannkuchredux2.exe 12   87.460362
# 11        taskset --cpu-list 5 ./game_of_life.exe 256   12.558226
# 14              taskset --cpu-list 5 ./grammatrix.exe   93.947041
# 53             taskset --cpu-list 5 ./knucleotide.exe   43.457097
# 31            taskset --cpu-list 5 ./knucleotide3.exe   45.305798
# 26                    taskset --cpu-list 5 ./main.exe   17.185935
# 19      taskset --cpu-list 5 ./mandelbrot6.exe 16_000   39.844158
# 36  taskset --cpu-list 5 menhir benchmarks/menhir/...  234.466711
# 51  taskset --cpu-list 5 menhir -v --table benchma...   83.834905
# 45  taskset --cpu-list 5 minilight-ocaml benchmark...   21.906600
# 13             taskset --cpu-list 5 ./regexredux2.exe   19.549511
# 7             taskset --cpu-list 5 ./test_lwt.exe 200   28.827723
# 20  taskset --cpu-list 5 ./thread_ring_lwt_stream....   11.261371
#
#     user_time_secs  sys_time_secs  maxrss_kB   codesize  \
# 12       17.398430       0.133970     283028  2449386.0
# 42       11.665649       0.060008     154996   237312.0
# 48      292.989665       0.351997     673148  4945689.0
# 6       103.794169       0.223996     392832  4945689.0
# 38       13.590144       0.176027     237776   965691.0
# 44       16.268530       0.163965     311528   965691.0
# 43      234.487010       0.300746     468072  1009821.0
# 25      566.072125       0.088662     139744  1009821.0
# 15       66.880451       1.580010    2810376   140709.0
# 30       78.605096       0.003999       3428   237597.0
# 29       87.459957       0.000000       3424   237673.0
# 11       12.549827       0.008001      19412    51882.0
# 14       93.566015       0.380008     507432   209767.0
# 53       43.192701       0.264004     403232   238452.0
# 31       45.117376       0.187989     270112   241101.0
# 26       17.185569       0.000000       6748   179836.0
# 19       39.839776       0.003999       3496   237258.0
# 36      231.249190       3.215960    5518428   797520.0
# 51       83.358132       0.476012     700632   797520.0
# 45       21.893911       0.011998      12396   303575.0
# 13       19.065215       0.483929     902176   237509.0
# 7        28.823330       0.003999       8328   434784.0
# 20       11.261009       0.000000       8568   351224.0
#
#                                             ocaml_url ocaml.version  \
# 12  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 42  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 48  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 6   https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 38  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 44  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 43  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 25  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 15  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 30  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 29  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 11  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 14  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 53  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 31  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 26  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 19  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 36  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 51  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 45  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 13  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 7   https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
# 20  https://github.com/ocaml/ocaml/archive/4.10.0....        4.10.0
#
#    ocaml.c_compiler  ... gc.promoted_words gc.major_words  \
# 12              gcc  ...          54255363       60420201
# 42              gcc  ...         270315861      270315861
# 48              gcc  ...         648185762      660023565
# 6               gcc  ...         317208662      328831788
# 38              gcc  ...          84924904       95514308
# 44              gcc  ...         124885556      140556185
# 43              gcc  ...         444610883     3254854686
# 25              gcc  ...        6206949578     6365128033
# 15              gcc  ...            715354     1300975367
# 30              gcc  ...                 0              0
# 29              gcc  ...                 0              0
# 11              gcc  ...               148        2101398
# 14              gcc  ...           1901776       68621873
# 53              gcc  ...           2362301       51016980
# 31              gcc  ...           1673977       34073271
# 26              gcc  ...            183503         183503
# 19              gcc  ...                 0              0
# 36              gcc  ...         427350062     1147738438
# 51              gcc  ...         328963733      467089362
# 45              gcc  ...          10618011       10634729
# 13              gcc  ...         167680277      240121205
# 7               gcc  ...          11331506       27780646
# 20              gcc  ...         428679938      428680946
#
#    gc.minor_collections gc.major_collections gc.heap_words gc.top_heap_words  \
# 12                 7887                   20      37309440          37309440
# 42                 3527                   63      18974208          18974208
# 48               273430                   68      80033280          80033280
# 6                 90142                   41      45758976          45758976
# 38                 2267                   29      28857856          28857856
# 44                 1621                   34      38164992          38164992
# 43                84452                  377      58503168          58503168
# 25               405888                 1527      16629248          16629248
# 15                14253                   32     357150208         357150208
# 30                    0                    0        126976            126976
# 29                    0                    0        126976            126976
# 11                    2                    2       2330624           2330624
# 14                  573                   16      66752512          66752512
# 53                  342                   10      87480320          87480320
# 31                  267                    7      57502208          57502208
# 26                 6329                    6        126976            126976
# 19                    0                    0        126976            126976
# 36                 9619                   35     705248768         705248768
# 51                35125                   61      91893760          91893760
# 45                37210                   57        760832            760832
# 13                  843                   29     109970944         109970944
# 7                  4519                  435        249856            249856
# 20                 8337                 2778        311296            311296
#
#     gc.mean_space_overhead  variant  gc.heap_chunks  gc.compactions
# 12                     NaN    Stock            35.0             0.0
# 42                     NaN    Stock            33.0             0.0
# 48                     NaN    Stock            39.0             0.0
# 6                      NaN    Stock            35.0             0.0
# 38                     NaN    Stock            36.0             0.0
# 44                     NaN    Stock            38.0             0.0
# 43                     NaN    Stock            32.0             0.0
# 25                     NaN    Stock            23.0             0.0
# 15                     NaN    Stock            54.0             0.0
# 30                     NaN    Stock             1.0             0.0
# 29                     NaN    Stock             1.0             0.0
# 11                     NaN    Stock            18.0             0.0
# 14                     NaN    Stock            42.0             0.0
# 53                     NaN    Stock            11.0             0.0
# 31                     NaN    Stock             3.0             0.0
# 26                     NaN    Stock             1.0             0.0
# 19                     NaN    Stock             1.0             0.0
# 36                     NaN    Stock            50.0             0.0
# 51                     NaN    Stock            43.0             0.0
# 45                     NaN    Stock            10.0             0.0
# 13                     NaN    Stock            16.0             0.0
# 7                      NaN    Stock             3.0             0.0
# 20                     NaN    Stock             4.0             0.0
#
# [23 rows x 28 columns]

# %%
df.loc[df['name'] == 'LU_decomposition.1024']
# Out:
#                      name                                           command  \
# 10  LU_decomposition.1024  taskset --cpu-list 5 ./LU_decomposition.exe 1024
# 10  LU_decomposition.1024  taskset --cpu-list 5 ./LU_decomposition.exe 1024
# 10  LU_decomposition.1024  taskset --cpu-list 5 ./LU_decomposition.exe 1024
# 10  LU_decomposition.1024  taskset --cpu-list 5 ./LU_decomposition.exe 1024
#
#     time_secs  user_time_secs  sys_time_secs  maxrss_kB  codesize  \
# 10   4.532988        4.504697       0.028004      37996   66666.0
# 10   4.218466        4.035983       0.003999      29668   51658.0
# 10   4.531972        4.515655       0.015998      38056   66666.0
# 10   4.385071        4.368755       0.015988      37916   75341.0
#
#                                             ocaml_url     ocaml.version  \
# 10  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
# 10  https://github.com/ocaml/ocaml/archive/4.10.0....            4.10.0
# 10  https://github.com/ocaml-multicore/ocaml-multi...  4.10.0+multicore
# 10  https://github.com/kayceesrk/ocaml-multicore/a...  4.10.0+multicore
#
#    ocaml.c_compiler  ... gc.promoted_words gc.major_words  \
# 10              gcc  ...               163        4194537
# 10              gcc  ...               162        4194470
# 10              gcc  ...               162        4194536
# 10              gcc  ...               163        4194537
#
#    gc.minor_collections gc.major_collections gc.heap_words gc.top_heap_words  \
# 10                 8217                    2       3182601           3182601
# 10                 8218                    4       5790208           5790208
# 10                 8217                    2       3182601           3182601
# 10                 8217                    2       3182601           3182601
#
#     gc.mean_space_overhead       variant  gc.heap_chunks  gc.compactions
# 10                3.494000  MC+RedZone32             NaN             NaN
# 10                     NaN         Stock             4.0             0.0
# 10                3.494098            MC             NaN             NaN
# 10                3.494000   MC+RedZone0             NaN             NaN
#
# [4 rows x 28 columns]

# %% [markdown]
# ### Projection example
#
# ```
# select name, variant, time_secs from df
# ```

# %%
df.filter(['name','variant','time_secs'])
# Out:
#                                          name       variant   time_secs
# 10                      LU_decomposition.1024  MC+RedZone32    4.532988
# 10                      LU_decomposition.1024         Stock    4.218466
# 10                      LU_decomposition.1024            MC    4.531972
# 10                      LU_decomposition.1024   MC+RedZone0    4.385071
# 22                          alt-ergo.fill.why            MC    2.566125
# 22                          alt-ergo.fill.why         Stock    2.021685
# 22                          alt-ergo.fill.why  MC+RedZone32    2.593185
# 22                          alt-ergo.fill.why   MC+RedZone0    2.616023
# 12                          alt-ergo.yyll.why         Stock   17.532885
# 12                          alt-ergo.yyll.why            MC   18.301929
# 12                          alt-ergo.yyll.why   MC+RedZone0   18.339121
# 12                          alt-ergo.yyll.why  MC+RedZone32   18.200624
# 34                                     bdd.26  MC+RedZone32    5.582651
# 34                                     bdd.26            MC    5.623276
# 34                                     bdd.26   MC+RedZone0    5.572424
# 34                                     bdd.26         Stock    5.270421
# 41                            binarytrees5.21   MC+RedZone0   12.296776
# 41                            binarytrees5.21            MC   12.691259
# 42                            binarytrees5.21         Stock   11.725996
# 41                            binarytrees5.21  MC+RedZone32   12.748200
# 33                 chameneos_redux_lwt.600000         Stock    2.084518
# 33                 chameneos_redux_lwt.600000  MC+RedZone32    2.258255
# 33                 chameneos_redux_lwt.600000   MC+RedZone0    2.259385
# 33                 chameneos_redux_lwt.600000            MC    2.250527
# 48               coq.AbstractInterpretation.v         Stock  293.342959
# 47               coq.AbstractInterpretation.v  MC+RedZone32  322.526510
# 47               coq.AbstractInterpretation.v            MC  323.478994
# 47               coq.AbstractInterpretation.v   MC+RedZone0  325.257178
# 6                           coq.BasicSyntax.v  MC+RedZone32  111.984415
# 6                           coq.BasicSyntax.v   MC+RedZone0  113.384733
# 6                           coq.BasicSyntax.v            MC  110.976984
# 6                           coq.BasicSyntax.v         Stock  104.018834
# 32                             cpdf.blacktext  MC+RedZone32    3.997935
# 32                             cpdf.blacktext   MC+RedZone0    4.017149
# 32                             cpdf.blacktext            MC    3.999818
# 32                             cpdf.blacktext         Stock    4.188315
# 37                                 cpdf.scale  MC+RedZone32   14.219408
# 37                                 cpdf.scale            MC   14.229265
# 38                                 cpdf.scale         Stock   13.766666
# 37                                 cpdf.scale   MC+RedZone0   14.371217
# 43                               cpdf.squeeze            MC   16.626318
# 44                               cpdf.squeeze         Stock   16.432945
# 43                               cpdf.squeeze  MC+RedZone32   16.630203
# 43                               cpdf.squeeze   MC+RedZone0   16.706276
# 8                        crout-decomposition.            MC    1.378919
# 8                        crout-decomposition.   MC+RedZone0    1.416446
# 8                        crout-decomposition.         Stock    1.327643
# 8                        crout-decomposition.  MC+RedZone32    1.378068
# 42                     cubicle.german_pfs.cub   MC+RedZone0  271.583435
# 42                     cubicle.german_pfs.cub            MC  271.654957
# 42                     cubicle.german_pfs.cub  MC+RedZone32  272.682828
# 43                     cubicle.german_pfs.cub         Stock  234.789072
# 25                   cubicle.szymanski_at.cub   MC+RedZone0  570.779414
# 25                   cubicle.szymanski_at.cub            MC  578.129767
# 25                   cubicle.szymanski_at.cub  MC+RedZone32  581.848810
# 25                   cubicle.szymanski_at.cub         Stock  566.162048
# 27                      durand-kerner-aberth.   MC+RedZone0    0.145797
# 27                      durand-kerner-aberth.  MC+RedZone32    0.153606
# 27                      durand-kerner-aberth.         Stock    0.138931
# 27                      durand-kerner-aberth.            MC    0.152575
# 15         evolutionary_algorithm.10000_10000            MC   71.845517
# 15         evolutionary_algorithm.10000_10000  MC+RedZone32   71.858201
# 15         evolutionary_algorithm.10000_10000         Stock   68.461066
# 15         evolutionary_algorithm.10000_10000   MC+RedZone0   74.323333
# 30                           fannkuchredux.12         Stock   78.609458
# 30                           fannkuchredux.12  MC+RedZone32   94.164035
# 30                           fannkuchredux.12   MC+RedZone0   98.387937
# 30                           fannkuchredux.12            MC   93.480126
# 29                          fannkuchredux2.12   MC+RedZone0   95.489403
# 29                          fannkuchredux2.12            MC   90.920677
# 29                          fannkuchredux2.12         Stock   87.460362
# 29                          fannkuchredux2.12  MC+RedZone32   90.992310
# 53                          fasta3.25_000_000   MC+RedZone0    8.464174
# 36                              menhir.ocamly            MC  259.400356
# 36                              menhir.ocamly         Stock  234.466711
# 36                              menhir.ocamly   MC+RedZone0  259.275777
# 36                              menhir.ocamly  MC+RedZone32  261.143221
# 1                           menhir.sql-parser  MC+RedZone32    7.327255
# 1                           menhir.sql-parser   MC+RedZone0    7.370447
# 1                           menhir.sql-parser            MC    7.262291
# 1                           menhir.sql-parser         Stock    6.891414
# 50                              menhir.sysver   MC+RedZone0   87.406347
# 50                              menhir.sysver            MC   87.514693
# 51                              menhir.sysver         Stock   83.834905
# 50                              menhir.sysver  MC+RedZone32   88.191317
# 44                        minilight.roomfront   MC+RedZone0   23.157055
# 44                        minilight.roomfront            MC   23.132667
# 44                        minilight.roomfront  MC+RedZone32   23.130167
# 45                        minilight.roomfront         Stock   21.906600
# 49                          naive-multilayer.            MC    4.535113
# 50                          naive-multilayer.         Stock    4.262039
# 49                          naive-multilayer.  MC+RedZone32    4.519197
# 49                          naive-multilayer.   MC+RedZone0    4.570641
# 28                           nbody.50_000_000         Stock    7.454929
# 28                           nbody.50_000_000   MC+RedZone0    7.629726
# 28                           nbody.50_000_000            MC    7.585259
# 28                           nbody.50_000_000  MC+RedZone32    7.658816
# 49                           pidigits5.10_000         Stock    6.261566
# 48                           pidigits5.10_000   MC+RedZone0    2.337219
# 48                           pidigits5.10_000            MC    2.342454
# 48                           pidigits5.10_000  MC+RedZone32    2.335723
# 24                          qr-decomposition.   MC+RedZone0    2.238775
# 24                          qr-decomposition.  MC+RedZone32    2.205298
# 24                          qr-decomposition.         Stock    2.075974
# 24                          qr-decomposition.            MC    2.206652
# 18                          quicksort.4000000         Stock    2.794134
# 18                          quicksort.4000000   MC+RedZone0    3.071453
# 18                          quicksort.4000000  MC+RedZone32    3.233472
# 18                          quicksort.4000000            MC    3.221767
# 13                               regexredux2.   MC+RedZone0   18.618700
# 13                               regexredux2.            MC   18.241336
# 13                               regexredux2.         Stock   19.549511
# 13                               regexredux2.  MC+RedZone32   18.253844
# 5                                   revcomp2.            MC    3.047961
# 5                                   revcomp2.  MC+RedZone32    3.047968
# 5                                   revcomp2.   MC+RedZone0    3.055184
# 5                                   revcomp2.         Stock    3.183821
# 51                         sequence_cps.10000   MC+RedZone0    1.910457
# 51                         sequence_cps.10000  MC+RedZone32    1.892806
# 52                         sequence_cps.10000         Stock    1.600767
# 51                         sequence_cps.10000            MC    1.890164
# 3               setrip.-enc_-rseed_1067894368   MC+RedZone0    1.620393
# 3               setrip.-enc_-rseed_1067894368  MC+RedZone32    1.576670
# 3               setrip.-enc_-rseed_1067894368            MC    1.628520
# 3               setrip.-enc_-rseed_1067894368         Stock    1.527823
# 40                        spectralnorm2.5_500   MC+RedZone0    7.811888
# 40                        spectralnorm2.5_500            MC    7.537976
# 40                        spectralnorm2.5_500  MC+RedZone32    7.537537
# 41                        spectralnorm2.5_500         Stock    8.107790
# 9                  test_decompress.64_524_288            MC    4.253654
# 9                  test_decompress.64_524_288         Stock    4.068778
# 9                  test_decompress.64_524_288  MC+RedZone32    4.231658
# 9                  test_decompress.64_524_288   MC+RedZone0    4.296637
# 7                                test_lwt.200         Stock   28.827723
# 7                                test_lwt.200  MC+RedZone32   23.286454
# 7                                test_lwt.200   MC+RedZone0   23.033881
# 7                                test_lwt.200            MC   22.533769
# 47                thread_ring_lwt_mvar.20_000         Stock    3.342148
# 46                thread_ring_lwt_mvar.20_000            MC    3.463112
# 46                thread_ring_lwt_mvar.20_000   MC+RedZone0    3.499324
# 46                thread_ring_lwt_mvar.20_000  MC+RedZone32    3.466957
# 20              thread_ring_lwt_stream.20_000         Stock   11.261371
# 20              thread_ring_lwt_stream.20_000   MC+RedZone0   11.027932
# 20              thread_ring_lwt_stream.20_000  MC+RedZone32   11.183574
# 20              thread_ring_lwt_stream.20_000            MC   11.099015
# 4                    yojson_ydump.sample.json         Stock    0.758916
# 4                    yojson_ydump.sample.json  MC+RedZone32    0.772634
# 4                    yojson_ydump.sample.json            MC    0.772098
# 4                    yojson_ydump.sample.json   MC+RedZone0    0.773514
# 39                             zarith_pi.5000         Stock    1.481425
# 38                             zarith_pi.5000            MC    0.588280
# 38                             zarith_pi.5000   MC+RedZone0    0.583206
# 38                             zarith_pi.5000  MC+RedZone32    0.582913

# %% [markdown]
# ## Helper functions

# %%
import numpy as np

nameMap = {}
nameMap['bdd.26'] = 'bdd'
nameMap['binarytrees5.21'] = 'binarytrees'
nameMap['chameneos_redux_lwt.600000'] = 'chameneos_redux_lwt'
nameMap['cpdf.blacktext'] = 'cpdf.blacktext'
nameMap['cpdf.scale'] = 'cpdf.scale'
nameMap['cpdf.squeeze'] = 'cpdf.squeeze'
nameMap['durand-kerner-aberth.'] = 'durand-kerner-aberth'
nameMap['fannkuchredux.12'] = 'fannkuchredux'
nameMap['fannkuchredux2.12'] = 'fannkuchredux2'
nameMap['fasta3.25_000_000'] = 'fasta3'
nameMap['fasta6.25_000_000'] = 'fasta6'
nameMap['fft.'] = 'fft'
nameMap['game_of_life.256'] = 'game_of_life'
nameMap['kb.'] = 'kb'
nameMap['kb_no_exc.'] = 'kb_no_exc'
nameMap['knucleotide.'] = 'knucleotide'
nameMap['knucleotide3.'] = 'knucleotide3'
nameMap['levinson-durbin.'] = 'levinson-durbin'
nameMap['lexifi-g2pp.'] = 'lexifi-g2pp'
nameMap['lu-decomposition.'] = 'lu-decomposition'
nameMap['mandelbrot6.16_000'] = 'mandelbrot6'
nameMap['matrix_multiplication.1024'] = 'matrix_mult'
nameMap['menhir.ocamly'] = 'menhir.ocamly'
nameMap['menhir.sql-parser'] = 'menhir.sql-parser'
nameMap['menhir.sysver'] = 'menhir.sysver'
nameMap['minilight.roomfront'] = 'minilight.roomfront'
nameMap['naive-multilayer.'] = 'naive-multilayer'
nameMap['nbody.50_000_000'] = 'nbody'
nameMap['pidigits5.10_000'] = 'pidigits5'
nameMap['qr-decomposition.'] = 'qr-decomposition'
nameMap['quicksort.4000000'] = 'quicksort'
nameMap['regexredux2.'] = 'regexredux2'
nameMap['revcomp2.'] = 'revcomp2'
nameMap['sequence_cps.10000'] = 'sequence_cps'
nameMap['setrip.-enc_-rseed_1067894368'] = 'setrip'
nameMap['spectralnorm2.5_500'] = 'spectralnorm2'
nameMap['test_decompress.64_524_288'] = 'decompress'
nameMap['test_lwt.200'] = 'test_lwt'
nameMap['thread_ring_lwt_mvar.20_000'] = 'thread_ring_lwt_mvar'
nameMap['thread_ring_lwt_stream.20_000'] = 'thread_ring_lwt_stream'
nameMap['yojson_ydump.sample.json'] = 'yojson_ydump'
nameMap['zarith_pi.5000'] = 'zarith_pi'
nameMap['LU_decomposition.1024'] = 'lu_decomposition'
nameMap['floyd_warshall.512'] = 'floyd_warshall'
nameMap['alt-ergo.fill.why'] = 'alt-ergo.fill.why'
nameMap['alt-ergo.yyll.why'] = 'alt-ergo.yyll.why'
nameMap['coq.AbstractInterpretation.v'] = 'coq.AbsInterp.v'
nameMap['coq.BasicSyntax.v'] = 'coq.BasicSyntax.v'
nameMap['crout-decomposition.'] = 'crout-decomposition'
nameMap['cubicle.german_pfs.cub'] = 'cubicle.german_pfs'
nameMap['cubicle.szymanski_at.cub'] = 'cubicle.szymanski_at'
nameMap['evolutionary_algorithm.10000_10000'] = 'evolutionary_algorithm'
nameMap['grammatrix.'] = 'gammatrix'
nameMap['imrin_mem_rw.10_000_50_000_20_100_000_000'] = 'imrin_mem_rw.reads'
nameMap['imrin_mem_rw.10_000_50_000_80_100_000_000'] = 'imrin_mem_rw.writes'



def remapName(n):
    return nameMap[n]

# returns a dictionary with {key = name : value : metric}
# the metric corresponds to the variant
def create_column(df, variant, metric):
    df = pd.DataFrame.copy(df)
    variant_metric_name = list([ zip(df[metric], df[x], df['name']) 
              for x in df.columns.array if x == "variant" ][0])
    name_metric = {n:t for (t, v, n) in variant_metric_name if v == variant}
#     print(name_metric)
    return name_metric

def add_display_name(df,variant, metric):
    name_metric = create_column(pd.DataFrame.copy(df), variant, metric)
#     print(name_metric)
    disp_name = [remapName(name)+" ("+str(round(name_metric[name], 2))+")" for name in df["name"]]
    df["display_name"] = pd.Series(disp_name, index=df.index)
    return df

def normalise(df,variant,topic,additionalTopics=[]):
    df = add_display_name(df,variant,topic)
    df = df.sort_values(["name","variant"])
    grouped = df.filter(items=['name',topic,'variant','display_name']+additionalTopics).groupby('variant')
    ndata_frames = []
    for group in grouped:
        (v,data) = group
        if(v != variant):
            data['b'+topic] = grouped.get_group(variant)[topic].values
            data[['n'+topic]] = data[[topic]].div(grouped.get_group(variant)[topic].values, axis=0)
            for t in additionalTopics:
#                 print(variant, t)
                data[[t]] = grouped.get_group(variant)[t].values
            ndata_frames.append(data)
    df = pd.concat (ndata_frames)
    return df

def plot_normalised(df,variant,topic,hueord=[]):
    df = pd.DataFrame.copy(df)
    df.sort_values(by=[topic],inplace=True)
    df[topic] = df[topic] - 1
    g = sns.catplot (x="display_name", y=topic, hue='variant', data = df, kind ='bar', 
                     aspect=4, bottom=1,hue_order=hueord)
    g.set_xticklabels(rotation=90,fontsize=18)
    g.ax.legend(loc=8)
    g._legend.remove()
    g.ax.set_xlabel("Benchmarks")
    return g
    # g.ax.set_yscale('log')

def geo_mean(iterable):
    a = np.array(iterable)
    return a.prod()**(1.0/len(a))

# %% [markdown]
# ## Time

# %%
g = sns.catplot (x='name', y='time_secs', hue='variant', data = df, kind ='bar', aspect=4)
g.set_xticklabels(rotation=90)

# %% [markdown]
# ### Normalised

# %%
ndf = normalise(df,baseline,'time_secs')
g = plot_normalised(ndf,baseline,'ntime_secs',hueord=["MC","MC+RedZone0","MC+RedZone32"])
g.ax.set_ylim(0.75,1.35)
g.ax.tick_params(axis='y',labelsize=18)
g.ax.legend(loc=2,fontsize=18)
g.ax.set_xlabel("Benchmarks",fontsize=18)
g.ax.set_ylabel("Normalized Time",fontsize=18)
g
# Out:
# <ipython-input-145-0253c60fb8b9>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["display_name"] = pd.Series(disp_name, index=df.index)

# %% [markdown]
# ### Savefig

# %%
g.savefig('sandmark_time.pdf')

# %% [markdown]
# ### geomean

# %%
for g in ndf.groupby('variant'):
    (v,_df) = g
    print(v,geo_mean(_df['ntime_secs'].values))
# Out:
# MC 0.9909322801954278
# MC+RedZone0 0.9976095636013624
# MC+RedZone32 0.9932941553358129

# %% [markdown]
# ## Top heap words

# %%
g = sns.catplot (x='name', y='gc.top_heap_words', hue='variant', data = df, kind ='bar', aspect=4)
g.set_xticklabels(rotation=90)

# %% [markdown]
# ### Normalised

# %%
ndf = normalise(df,baseline,'gc.top_heap_words')
plot_normalised(ndf,baseline,'ngc.top_heap_words')
# Out:
# <ipython-input-106-6400779b5262>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["display_name"] = pd.Series(disp_name, index=df.index)

# %% [markdown]
# ## Max RSS (KB)

# %%
g = sns.catplot (x='name', y='maxrss_kB', hue='variant', data = df, kind ='bar', aspect=4)
g.set_xticklabels(rotation=90)

# %% [markdown]
# ### Normalised

# %%
ndf = normalise(df,baseline,'maxrss_kB')
plot_normalised(ndf,baseline,'nmaxrss_kB')
# Out:
# <ipython-input-106-6400779b5262>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["display_name"] = pd.Series(disp_name, index=df.index)

# %% [markdown]
# ## Major Collections

# %%
g = sns.catplot (x='name', y='gc.major_collections', hue='variant', data = df, kind ='bar', aspect=4)
g.set_xticklabels(rotation=90)

# %% [markdown]
# ### Normalised

# %%
ndf = normalise(df,baseline,'gc.major_collections')
plot_normalised(ndf,baseline,'ngc.major_collections')
ndf
# Out:
# <ipython-input-106-6400779b5262>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["display_name"] = pd.Series(disp_name, index=df.index)
#                                          name  gc.major_collections  \
# 10                      LU_decomposition.1024                     2
# 22                          alt-ergo.fill.why                    17
# 12                          alt-ergo.yyll.why                    26
# 34                                     bdd.26                     9
# 41                            binarytrees5.21                    68
# 33                 chameneos_redux_lwt.600000                    62
# 47               coq.AbstractInterpretation.v                    78
# 6                           coq.BasicSyntax.v                    42
# 32                             cpdf.blacktext                    13
# 37                                 cpdf.scale                    27
# 43                               cpdf.squeeze                    32
# 8                        crout-decomposition.                     7
# 42                     cubicle.german_pfs.cub                   455
# 25                   cubicle.szymanski_at.cub                  1464
# 27                      durand-kerner-aberth.                    18
# 15         evolutionary_algorithm.10000_10000                    30
# 30                           fannkuchredux.12                     0
# 29                          fannkuchredux2.12                     0
# 53                          fasta3.25_000_000                     1
# 23                          fasta6.25_000_000                     2
# 2                                        fft.                    32
# 16                         floyd_warshall.512                    25
# 11                           game_of_life.256                     3
# 14                                grammatrix.                    15
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000                    11
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000                    16
# 45                                        kb.                   231
# 35                                 kb_no_exc.                   188
# 52                               knucleotide.                     7
# 31                              knucleotide3.                     6
# 0                            levinson-durbin.                  1898
# 26                               lexifi-g2pp.                    12
# 19                         mandelbrot6.16_000                     0
# 21                 matrix_multiplication.1024                     4
# 36                              menhir.ocamly                    37
# 1                           menhir.sql-parser                    21
# 50                              menhir.sysver                    57
# 44                        minilight.roomfront                    58
# 49                          naive-multilayer.                   152
# 28                           nbody.50_000_000                     0
# 48                           pidigits5.10_000                  3146
# 24                          qr-decomposition.                    31
# 18                          quicksort.4000000                     1
# 13                               regexredux2.                    22
# 5                                   revcomp2.                    17
# 51                         sequence_cps.10000                   469
# 3               setrip.-enc_-rseed_1067894368                    14
# 40                        spectralnorm2.5_500                     6
# 9                  test_decompress.64_524_288                   455
# 7                                test_lwt.200                  1234
# 46                thread_ring_lwt_mvar.20_000                  1178
# 20              thread_ring_lwt_stream.20_000                  2317
# 4                    yojson_ydump.sample.json                    18
# 38                             zarith_pi.5000                   747
# 10                      LU_decomposition.1024                     2
# 22                          alt-ergo.fill.why                    17
# 12                          alt-ergo.yyll.why                    26
# 34                                     bdd.26                     9
# 41                            binarytrees5.21                    68
# 33                 chameneos_redux_lwt.600000                    62
# 47               coq.AbstractInterpretation.v                    78
# 6                           coq.BasicSyntax.v                    42
# 32                             cpdf.blacktext                    13
# 37                                 cpdf.scale                    27
# 43                               cpdf.squeeze                    32
# 8                        crout-decomposition.                     7
# 42                     cubicle.german_pfs.cub                   457
# 25                   cubicle.szymanski_at.cub                  1474
# 27                      durand-kerner-aberth.                    18
# 15         evolutionary_algorithm.10000_10000                    30
# 30                           fannkuchredux.12                     0
# 29                          fannkuchredux2.12                     0
# 53                          fasta3.25_000_000                     1
# 23                          fasta6.25_000_000                     2
# 2                                        fft.                    32
# 16                         floyd_warshall.512                    25
# 11                           game_of_life.256                     3
# 14                                grammatrix.                    15
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000                    11
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000                    16
# 45                                        kb.                   232
# 35                                 kb_no_exc.                   188
# 52                               knucleotide.                     7
# 31                              knucleotide3.                     6
# 0                            levinson-durbin.                  1906
# 26                               lexifi-g2pp.                    12
# 19                         mandelbrot6.16_000                     0
# 21                 matrix_multiplication.1024                     4
# 36                              menhir.ocamly                    37
# 1                           menhir.sql-parser                    21
# 50                              menhir.sysver                    57
# 44                        minilight.roomfront                    58
# 49                          naive-multilayer.                   152
# 28                           nbody.50_000_000                     0
# 48                           pidigits5.10_000                  3146
# 24                          qr-decomposition.                    31
# 18                          quicksort.4000000                     1
# 13                               regexredux2.                    22
# 5                                   revcomp2.                    17
# 51                         sequence_cps.10000                   469
# 3               setrip.-enc_-rseed_1067894368                    13
# 40                        spectralnorm2.5_500                     6
# 9                  test_decompress.64_524_288                   455
# 7                                test_lwt.200                  1234
# 46                thread_ring_lwt_mvar.20_000                  1178
# 20              thread_ring_lwt_stream.20_000                  2317
# 4                    yojson_ydump.sample.json                    18
# 38                             zarith_pi.5000                   747
# 10                      LU_decomposition.1024                     2
# 22                          alt-ergo.fill.why                    17
# 12                          alt-ergo.yyll.why                    26
# 34                                     bdd.26                     9
# 41                            binarytrees5.21                    68
# 33                 chameneos_redux_lwt.600000                    62
# 47               coq.AbstractInterpretation.v                    78
# 6                           coq.BasicSyntax.v                    42
# 32                             cpdf.blacktext                    13
# 37                                 cpdf.scale                    27
# 43                               cpdf.squeeze                    32
# 8                        crout-decomposition.                     7
# 42                     cubicle.german_pfs.cub                   457
# 25                   cubicle.szymanski_at.cub                  1474
# 27                      durand-kerner-aberth.                    18
# 15         evolutionary_algorithm.10000_10000                    30
# 30                           fannkuchredux.12                     0
# 29                          fannkuchredux2.12                     0
# 53                          fasta3.25_000_000                     1
# 23                          fasta6.25_000_000                     2
# 2                                        fft.                    32
# 16                         floyd_warshall.512                    25
# 11                           game_of_life.256                     3
# 14                                grammatrix.                    15
# 17  imrin_mem_rw.10_000_50_000_20_100_000_000                    11
# 39  imrin_mem_rw.10_000_50_000_80_100_000_000                    16
# 45                                        kb.                   232
# 35                                 kb_no_exc.                   188
# 52                               knucleotide.                     7
# 31                              knucleotide3.                     6
# 0                            levinson-durbin.                  1906
# 26                               lexifi-g2pp.                    12
# 19                         mandelbrot6.16_000                     0
# 21                 matrix_multiplication.1024                     4
# 36                              menhir.ocamly                    37
# 1                           menhir.sql-parser                    21
# 50                              menhir.sysver                    57
# 44                        minilight.roomfront                    58
# 49                          naive-multilayer.                   152
# 28                           nbody.50_000_000                     0
# 48                           pidigits5.10_000                  3146
# 24                          qr-decomposition.                    31
# 18                          quicksort.4000000                     1
# 13                               regexredux2.                    22
# 5                                   revcomp2.                    17
# 51                         sequence_cps.10000                   469
# 3               setrip.-enc_-rseed_1067894368                    13
# 40                        spectralnorm2.5_500                     6
# 9                  test_decompress.64_524_288                   455
# 7                                test_lwt.200                  1234
# 46                thread_ring_lwt_mvar.20_000                  1178
# 20              thread_ring_lwt_stream.20_000                  2317
# 4                    yojson_ydump.sample.json                    18
# 38                             zarith_pi.5000                   747
#
#          variant                   display_name  bgc.major_collections  \
# 10            MC           lu_decomposition (4)                      4
# 22            MC         alt-ergo.fill.why (13)                     13
# 12            MC         alt-ergo.yyll.why (20)                     20
# 34            MC                       bdd (11)                     11
# 41            MC               binarytrees (63)                     63
# 33            MC      chameneos_redux_lwt (202)                    202
# 47            MC           coq.AbsInterp.v (68)                     68
# 6             MC         coq.BasicSyntax.v (41)                     41
# 32            MC            cpdf.blacktext (15)                     15
# 37            MC                cpdf.scale (29)                     29
# 43            MC              cpdf.squeeze (34)                     34
# 8             MC       crout-decomposition (10)                     10
# 42            MC       cubicle.german_pfs (377)                    377
# 25            MC    cubicle.szymanski_at (1527)                   1527
# 27            MC      durand-kerner-aberth (83)                     83
# 15            MC    evolutionary_algorithm (32)                     32
# 30            MC              fannkuchredux (0)                      0
# 29            MC             fannkuchredux2 (0)                      0
# 53            MC                     fasta3 (0)                      0
# 23            MC                     fasta6 (1)                      1
# 2             MC                       fft (30)                     30
# 16            MC            floyd_warshall (21)                     21
# 11            MC               game_of_life (2)                      2
# 14            MC                 gammatrix (16)                     16
# 17            MC         imrin_mem_rw.reads (8)                      8
# 39            MC       imrin_mem_rw.writes (10)                     10
# 45            MC                       kb (324)                    324
# 35            MC                kb_no_exc (236)                    236
# 52            MC               knucleotide (10)                     10
# 31            MC               knucleotide3 (7)                      7
# 0             MC         levinson-durbin (1894)                   1894
# 26            MC                lexifi-g2pp (6)                      6
# 19            MC                mandelbrot6 (0)                      0
# 21            MC                matrix_mult (6)                      6
# 36            MC             menhir.ocamly (35)                     35
# 1             MC         menhir.sql-parser (22)                     22
# 50            MC             menhir.sysver (61)                     61
# 44            MC       minilight.roomfront (57)                     57
# 49            MC         naive-multilayer (141)                    141
# 28            MC                      nbody (0)                      0
# 48            MC               pidigits5 (2689)                   2689
# 24            MC          qr-decomposition (45)                     45
# 18            MC                  quicksort (0)                      0
# 13            MC               regexredux2 (29)                     29
# 5             MC                  revcomp2 (19)                     19
# 51            MC             sequence_cps (774)                    774
# 3             MC                     setrip (9)                      9
# 40            MC              spectralnorm2 (5)                      5
# 9             MC               decompress (522)                    522
# 7             MC                 test_lwt (435)                    435
# 46            MC    thread_ring_lwt_mvar (1763)                   1763
# 20            MC  thread_ring_lwt_stream (2778)                   2778
# 4             MC              yojson_ydump (17)                     17
# 38            MC                zarith_pi (642)                    642
# 10   MC+RedZone0           lu_decomposition (4)                      4
# 22   MC+RedZone0         alt-ergo.fill.why (13)                     13
# 12   MC+RedZone0         alt-ergo.yyll.why (20)                     20
# 34   MC+RedZone0                       bdd (11)                     11
# 41   MC+RedZone0               binarytrees (63)                     63
# 33   MC+RedZone0      chameneos_redux_lwt (202)                    202
# 47   MC+RedZone0           coq.AbsInterp.v (68)                     68
# 6    MC+RedZone0         coq.BasicSyntax.v (41)                     41
# 32   MC+RedZone0            cpdf.blacktext (15)                     15
# 37   MC+RedZone0                cpdf.scale (29)                     29
# 43   MC+RedZone0              cpdf.squeeze (34)                     34
# 8    MC+RedZone0       crout-decomposition (10)                     10
# 42   MC+RedZone0       cubicle.german_pfs (377)                    377
# 25   MC+RedZone0    cubicle.szymanski_at (1527)                   1527
# 27   MC+RedZone0      durand-kerner-aberth (83)                     83
# 15   MC+RedZone0    evolutionary_algorithm (32)                     32
# 30   MC+RedZone0              fannkuchredux (0)                      0
# 29   MC+RedZone0             fannkuchredux2 (0)                      0
# 53   MC+RedZone0                     fasta3 (0)                      0
# 23   MC+RedZone0                     fasta6 (1)                      1
# 2    MC+RedZone0                       fft (30)                     30
# 16   MC+RedZone0            floyd_warshall (21)                     21
# 11   MC+RedZone0               game_of_life (2)                      2
# 14   MC+RedZone0                 gammatrix (16)                     16
# 17   MC+RedZone0         imrin_mem_rw.reads (8)                      8
# 39   MC+RedZone0       imrin_mem_rw.writes (10)                     10
# 45   MC+RedZone0                       kb (324)                    324
# 35   MC+RedZone0                kb_no_exc (236)                    236
# 52   MC+RedZone0               knucleotide (10)                     10
# 31   MC+RedZone0               knucleotide3 (7)                      7
# 0    MC+RedZone0         levinson-durbin (1894)                   1894
# 26   MC+RedZone0                lexifi-g2pp (6)                      6
# 19   MC+RedZone0                mandelbrot6 (0)                      0
# 21   MC+RedZone0                matrix_mult (6)                      6
# 36   MC+RedZone0             menhir.ocamly (35)                     35
# 1    MC+RedZone0         menhir.sql-parser (22)                     22
# 50   MC+RedZone0             menhir.sysver (61)                     61
# 44   MC+RedZone0       minilight.roomfront (57)                     57
# 49   MC+RedZone0         naive-multilayer (141)                    141
# 28   MC+RedZone0                      nbody (0)                      0
# 48   MC+RedZone0               pidigits5 (2689)                   2689
# 24   MC+RedZone0          qr-decomposition (45)                     45
# 18   MC+RedZone0                  quicksort (0)                      0
# 13   MC+RedZone0               regexredux2 (29)                     29
# 5    MC+RedZone0                  revcomp2 (19)                     19
# 51   MC+RedZone0             sequence_cps (774)                    774
# 3    MC+RedZone0                     setrip (9)                      9
# 40   MC+RedZone0              spectralnorm2 (5)                      5
# 9    MC+RedZone0               decompress (522)                    522
# 7    MC+RedZone0                 test_lwt (435)                    435
# 46   MC+RedZone0    thread_ring_lwt_mvar (1763)                   1763
# 20   MC+RedZone0  thread_ring_lwt_stream (2778)                   2778
# 4    MC+RedZone0              yojson_ydump (17)                     17
# 38   MC+RedZone0                zarith_pi (642)                    642
# 10  MC+RedZone32           lu_decomposition (4)                      4
# 22  MC+RedZone32         alt-ergo.fill.why (13)                     13
# 12  MC+RedZone32         alt-ergo.yyll.why (20)                     20
# 34  MC+RedZone32                       bdd (11)                     11
# 41  MC+RedZone32               binarytrees (63)                     63
# 33  MC+RedZone32      chameneos_redux_lwt (202)                    202
# 47  MC+RedZone32           coq.AbsInterp.v (68)                     68
# 6   MC+RedZone32         coq.BasicSyntax.v (41)                     41
# 32  MC+RedZone32            cpdf.blacktext (15)                     15
# 37  MC+RedZone32                cpdf.scale (29)                     29
# 43  MC+RedZone32              cpdf.squeeze (34)                     34
# 8   MC+RedZone32       crout-decomposition (10)                     10
# 42  MC+RedZone32       cubicle.german_pfs (377)                    377
# 25  MC+RedZone32    cubicle.szymanski_at (1527)                   1527
# 27  MC+RedZone32      durand-kerner-aberth (83)                     83
# 15  MC+RedZone32    evolutionary_algorithm (32)                     32
# 30  MC+RedZone32              fannkuchredux (0)                      0
# 29  MC+RedZone32             fannkuchredux2 (0)                      0
# 53  MC+RedZone32                     fasta3 (0)                      0
# 23  MC+RedZone32                     fasta6 (1)                      1
# 2   MC+RedZone32                       fft (30)                     30
# 16  MC+RedZone32            floyd_warshall (21)                     21
# 11  MC+RedZone32               game_of_life (2)                      2
# 14  MC+RedZone32                 gammatrix (16)                     16
# 17  MC+RedZone32         imrin_mem_rw.reads (8)                      8
# 39  MC+RedZone32       imrin_mem_rw.writes (10)                     10
# 45  MC+RedZone32                       kb (324)                    324
# 35  MC+RedZone32                kb_no_exc (236)                    236
# 52  MC+RedZone32               knucleotide (10)                     10
# 31  MC+RedZone32               knucleotide3 (7)                      7
# 0   MC+RedZone32         levinson-durbin (1894)                   1894
# 26  MC+RedZone32                lexifi-g2pp (6)                      6
# 19  MC+RedZone32                mandelbrot6 (0)                      0
# 21  MC+RedZone32                matrix_mult (6)                      6
# 36  MC+RedZone32             menhir.ocamly (35)                     35
# 1   MC+RedZone32         menhir.sql-parser (22)                     22
# 50  MC+RedZone32             menhir.sysver (61)                     61
# 44  MC+RedZone32       minilight.roomfront (57)                     57
# 49  MC+RedZone32         naive-multilayer (141)                    141
# 28  MC+RedZone32                      nbody (0)                      0
# 48  MC+RedZone32               pidigits5 (2689)                   2689
# 24  MC+RedZone32          qr-decomposition (45)                     45
# 18  MC+RedZone32                  quicksort (0)                      0
# 13  MC+RedZone32               regexredux2 (29)                     29
# 5   MC+RedZone32                  revcomp2 (19)                     19
# 51  MC+RedZone32             sequence_cps (774)                    774
# 3   MC+RedZone32                     setrip (9)                      9
# 40  MC+RedZone32              spectralnorm2 (5)                      5
# 9   MC+RedZone32               decompress (522)                    522
# 7   MC+RedZone32                 test_lwt (435)                    435
# 46  MC+RedZone32    thread_ring_lwt_mvar (1763)                   1763
# 20  MC+RedZone32  thread_ring_lwt_stream (2778)                   2778
# 4   MC+RedZone32              yojson_ydump (17)                     17
# 38  MC+RedZone32                zarith_pi (642)                    642
#
#     ngc.major_collections
# 10               0.500000
# 22               1.307692
# 12               1.300000
# 34               0.818182
# 41               1.079365
# 33               0.306931
# 47               1.147059
# 6                1.024390
# 32               0.866667
# 37               0.931034
# 43               0.941176
# 8                0.700000
# 42               1.206897
# 25               0.958743
# 27               0.216867
# 15               0.937500
# 30                    NaN
# 29                    NaN
# 53                    inf
# 23               2.000000
# 2                1.066667
# 16               1.190476
# 11               1.500000
# 14               0.937500
# 17               1.375000
# 39               1.600000
# 45               0.712963
# 35               0.796610
# 52               0.700000
# 31               0.857143
# 0                1.002112
# 26               2.000000
# 19                    NaN
# 21               0.666667
# 36               1.057143
# 1                0.954545
# 50               0.934426
# 44               1.017544
# 49               1.078014
# 28                    NaN
# 48               1.169952
# 24               0.688889
# 18                    inf
# 13               0.758621
# 5                0.894737
# 51               0.605943
# 3                1.555556
# 40               1.200000
# 9                0.871648
# 7                2.836782
# 46               0.668179
# 20               0.834053
# 4                1.058824
# 38               1.163551
# 10               0.500000
# 22               1.307692
# 12               1.300000
# 34               0.818182
# 41               1.079365
# 33               0.306931
# 47               1.147059
# 6                1.024390
# 32               0.866667
# 37               0.931034
# 43               0.941176
# 8                0.700000
# 42               1.212202
# 25               0.965291
# 27               0.216867
# 15               0.937500
# 30                    NaN
# 29                    NaN
# 53                    inf
# 23               2.000000
# 2                1.066667
# 16               1.190476
# 11               1.500000
# 14               0.937500
# 17               1.375000
# 39               1.600000
# 45               0.716049
# 35               0.796610
# 52               0.700000
# 31               0.857143
# 0                1.006336
# 26               2.000000
# 19                    NaN
# 21               0.666667
# 36               1.057143
# 1                0.954545
# 50               0.934426
# 44               1.017544
# 49               1.078014
# 28                    NaN
# 48               1.169952
# 24               0.688889
# 18                    inf
# 13               0.758621
# 5                0.894737
# 51               0.605943
# 3                1.444444
# 40               1.200000
# 9                0.871648
# 7                2.836782
# 46               0.668179
# 20               0.834053
# 4                1.058824
# 38               1.163551
# 10               0.500000
# 22               1.307692
# 12               1.300000
# 34               0.818182
# 41               1.079365
# 33               0.306931
# 47               1.147059
# 6                1.024390
# 32               0.866667
# 37               0.931034
# 43               0.941176
# 8                0.700000
# 42               1.212202
# 25               0.965291
# 27               0.216867
# 15               0.937500
# 30                    NaN
# 29                    NaN
# 53                    inf
# 23               2.000000
# 2                1.066667
# 16               1.190476
# 11               1.500000
# 14               0.937500
# 17               1.375000
# 39               1.600000
# 45               0.716049
# 35               0.796610
# 52               0.700000
# 31               0.857143
# 0                1.006336
# 26               2.000000
# 19                    NaN
# 21               0.666667
# 36               1.057143
# 1                0.954545
# 50               0.934426
# 44               1.017544
# 49               1.078014
# 28                    NaN
# 48               1.169952
# 24               0.688889
# 18                    inf
# 13               0.758621
# 5                0.894737
# 51               0.605943
# 3                1.444444
# 40               1.200000
# 9                0.871648
# 7                2.836782
# 46               0.668179
# 20               0.834053
# 4                1.058824
# 38               1.163551

# %% [markdown]
# ## Major words

# %%
g = sns.catplot (x='name', y='gc.major_words', hue='variant', data = df, kind ='bar', aspect=4)
g.set_xticklabels(rotation=90)

# %% [markdown]
# ### Normalised

# %%
ndf = normalise(df,baseline,'gc.major_words')
plot_normalised(ndf,baseline,'ngc.major_words')
# Out:
# <ipython-input-106-6400779b5262>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["display_name"] = pd.Series(disp_name, index=df.index)

# %% [markdown]
# ## Minor Collections

# %%
g = sns.catplot (x='name', y='gc.minor_collections', hue='variant', data = df, kind ='bar', aspect=4)
g.set_xticklabels(rotation=90)

# %%
ndf = normalise(df,baseline,'gc.minor_collections')
plot_normalised(ndf,baseline,'ngc.minor_collections')
# Out:
# <ipython-input-106-6400779b5262>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["display_name"] = pd.Series(disp_name, index=df.index)

# %% [markdown]
# ## Codesize

# %%
g = sns.catplot (x='name', y='codesize', hue='variant', data = df, kind ='bar', aspect=4)
g.set_xticklabels(rotation=90)

# %% [markdown]
# ### Normalised

# %%
ndf = normalise(df,baseline,'codesize')
g = plot_normalised(ndf,baseline,'ncodesize',hueord=["MC","MC+RedZone0","MC+RedZone32"])
g.ax.legend(loc=2,fontsize=18)
g.ax.tick_params(axis='y',labelsize=18)
g.ax.set_xlabel("Benchmarks",fontsize=18)
g.ax.set_ylabel("Normalized OCaml text section size (OTSS)",fontsize=18)
g
# Out:
# <ipython-input-145-0253c60fb8b9>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["display_name"] = pd.Series(disp_name, index=df.index)

# %% [markdown]
# ### Savefig

# %%
g.savefig('sandmark_codesize.pdf')

# %% [markdown]
# ### Geomean

# %%
for g in ndf.groupby('variant'):
    (v,_df) = g
    print(v,geo_mean(_df['ncodesize'].values))
# Out:
# MC 1.1918413224499307
# MC+RedZone0 1.2941794575856125
# MC+RedZone32 1.1918254500325614
